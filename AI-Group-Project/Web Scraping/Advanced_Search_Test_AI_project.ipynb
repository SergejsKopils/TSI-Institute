# %% [markdown]
# <a href="https://colab.research.google.com/github/NataKrj/AI-project-2024/blob/main/Web%20Scraping/Advanced_Search_Test_AI_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Load the uploaded CSV file to examine its structure
file_path = '/content/1_0_50_company_analysis_results.csv'
data = pd.read_csv(file_path)

# Display the first few rows of the dataset to understand its structure
data.head()
# Out:
#                                 company  \
# 0  FORTUNEMAKER INVESTMENTS CORPORATION
# 1  FORTUNEMAKER INVESTMENTS CORPORATION
# 2  FORTUNEMAKER INVESTMENTS CORPORATION
# 3  FORTUNEMAKER INVESTMENTS CORPORATION
# 4  FORTUNEMAKER INVESTMENTS CORPORATION
#
#                                                  url  \
# 0  https://www.forbes.com/sites/daveknox/2022/07/...
# 1                               https://fortune.com/
# 2  https://foe.org/blog/2014-04-the-schwarzenegge...
# 3  https://www.inc.com/jeff-haden/arnold-schwarze...
# 4  https://www.globalwitness.org/en/archive/schwa...
#
#                                       extracted_text  related_keywords  \
# 0  Why Brain Health Is Patrick Schwarzenegger’s L...          No match
# 1  Fortune - Fortune 500 Daily & Breaking Busines...              debt
# 2  The Schwarzenegger dilemma:Years of investing ...          No match
# 3                                                NaN          No match
# 4  Schwarzenegger’s multi-million dollar ‘robo-fu...  court, violation
#
#     risk_level  risk_code
# 0     Low Risk          0
# 1  Medium Risk          1
# 2     Low Risk          0
# 3     Low Risk          0
# 4  Medium Risk          1

# %%
# Add a column to check if the company's name appears in the extracted text
data['text_relates_to_company'] = data.apply(
    lambda row: row['company'].lower() in str(row['extracted_text']).lower(), axis=1
)

# Count how many texts are related to the company and display examples
related_counts = data['text_relates_to_company'].value_counts()
examples_related = data[data['text_relates_to_company'] == True].head(5)
examples_not_related = data[data['text_relates_to_company'] == False].head(5)

related_counts, examples_related, examples_not_related
# Out:
# (text_relates_to_company
#  False    478
#  True      22
#  Name: count, dtype: int64,
#                              company  \
#  40  SKY-BLUE GIFTS & TOYS CO., LTD.
#  42  SKY-BLUE GIFTS & TOYS CO., LTD.
#  44  SKY-BLUE GIFTS & TOYS CO., LTD.
#  46  SKY-BLUE GIFTS & TOYS CO., LTD.
#  52         KENT DEVELOPMENT LIMITED
#
#                                                    url  \
#  40                        http://www.sky-blue.com.cn/
#  42         http://www.sky-blue.com.cn/en/contact.html
#  44  http://www.sky-blue.com.cn/en/product_d/id/98....
#  46  http://www.sky-blue.com.cn/en/product_d/id/104...
#  52  https://find-and-update.company-information.se...
#
#                                         extracted_text related_keywords  \
#  40  SKY-BLUE Quality Toys Since 2004   Sky-Blue ...         No match
#  42  CONTACT US - SKY-BLUE Quality Toys Since 2004 ...         No match
#  44  Balancing Bike-Red - SKY-BLUE Quality Toys Sin...         No match
#  46  Wooden Train Set 50PCS - SKY-BLUE Quality Toys...         No match
#  52  KENT DEVELOPMENT LIMITED overview - Find and u...         No match
#
#     risk_level  risk_code  text_relates_to_company
#  40   Low Risk          0                     True
#  42   Low Risk          0                     True
#  44   Low Risk          0                     True
#  46   Low Risk          0                     True
#  52   Low Risk          0                     True  ,
#                                  company  \
#  0  FORTUNEMAKER INVESTMENTS CORPORATION
#  1  FORTUNEMAKER INVESTMENTS CORPORATION
#  2  FORTUNEMAKER INVESTMENTS CORPORATION
#  3  FORTUNEMAKER INVESTMENTS CORPORATION
#  4  FORTUNEMAKER INVESTMENTS CORPORATION
#
#                                                   url  \
#  0  https://www.forbes.com/sites/daveknox/2022/07/...
#  1                               https://fortune.com/
#  2  https://foe.org/blog/2014-04-the-schwarzenegge...
#  3  https://www.inc.com/jeff-haden/arnold-schwarze...
#  4  https://www.globalwitness.org/en/archive/schwa...
#
#                                        extracted_text  related_keywords  \
#  0  Why Brain Health Is Patrick Schwarzenegger’s L...          No match
#  1  Fortune - Fortune 500 Daily & Breaking Busines...              debt
#  2  The Schwarzenegger dilemma:Years of investing ...          No match
#  3                                                NaN          No match
#  4  Schwarzenegger’s multi-million dollar ‘robo-fu...  court, violation
#
#      risk_level  risk_code  text_relates_to_company
#  0     Low Risk          0                    False
#  1  Medium Risk          1                    False
#  2     Low Risk          0                    False
#  3     Low Risk          0                    False
#  4  Medium Risk          1                    False  )

# %%
import spacy

# Load the spaCy language model
nlp = spacy.load("en_core_web_sm")

# Function to perform entity recognition and check if company name appears in entities
def analyze_text_with_nlp(row):
    if pd.isna(row['extracted_text']):
        return False
    doc = nlp(row['extracted_text'])
    entities = [ent.text.lower() for ent in doc.ents if ent.label_ in ["ORG", "PRODUCT", "GPE"]]
    company_name_lower = row['company'].lower()
    return any(company_name_lower in entity for entity in entities)

# Apply the analysis to the dataset
data['nlp_analysis_relates_to_company'] = data.apply(analyze_text_with_nlp, axis=1)

# Count results and display examples
nlp_related_counts = data['nlp_analysis_relates_to_company'].value_counts()
nlp_examples_related = data[data['nlp_analysis_relates_to_company'] == True].head(5)
nlp_examples_not_related = data[data['nlp_analysis_relates_to_company'] == False].head(5)

nlp_related_counts, nlp_examples_related, nlp_examples_not_related
# Out:
# (nlp_analysis_relates_to_company
#  False    485
#  True      15
#  Name: count, dtype: int64,
#                          company  \
#  52     KENT DEVELOPMENT LIMITED
#  104       VICTORY GROUP LIMITED
#  152      FORTUNE PALACE LIMITED
#  153      FORTUNE PALACE LIMITED
#  299  Alvear Investments Limited
#
#                                                     url  \
#  52   https://find-and-update.company-information.se...
#  104                              https://victoryg.com/
#  152  https://find-and-update.company-information.se...
#  153  https://www.datocapital.vg/companies/Fortune-P...
#  299      https://offshoreleaks.icij.org/nodes/12204276
#
#                                          extracted_text  \
#  52   KENT DEVELOPMENT LIMITED overview - Find and u...
#  104            Victory Group Limited home1 home2 home3
#  152  LIN'S FORTUNE PALACE LIMITED people - Find and...
#  153  Fortune Palace Investment CORP Dato Capital Ho...
#  299  STEPHEN KAMALIA MIKHAIL | ICIJ Offshore Leaks ...
#
#                related_keywords risk_level  risk_code  text_relates_to_company  \
#  52                    No match   Low Risk          0                     True
#  104                   No match   Low Risk          0                     True
#  152                   No match   Low Risk          0                     True
#  153                   No match   Low Risk          0                     True
#  299  corruption, investigation  High Risk          2                     True
#
#       nlp_analysis_relates_to_company
#  52                              True
#  104                             True
#  152                             True
#  153                             True
#  299                             True  ,
#                                  company  \
#  0  FORTUNEMAKER INVESTMENTS CORPORATION
#  1  FORTUNEMAKER INVESTMENTS CORPORATION
#  2  FORTUNEMAKER INVESTMENTS CORPORATION
#  3  FORTUNEMAKER INVESTMENTS CORPORATION
#  4  FORTUNEMAKER INVESTMENTS CORPORATION
#
#                                                   url  \
#  0  https://www.forbes.com/sites/daveknox/2022/07/...
#  1                               https://fortune.com/
#  2  https://foe.org/blog/2014-04-the-schwarzenegge...
#  3  https://www.inc.com/jeff-haden/arnold-schwarze...
#  4  https://www.globalwitness.org/en/archive/schwa...
#
#                                        extracted_text  related_keywords  \
#  0  Why Brain Health Is Patrick Schwarzenegger’s L...          No match
#  1  Fortune - Fortune 500 Daily & Breaking Busines...              debt
#  2  The Schwarzenegger dilemma:Years of investing ...          No match
#  3                                                NaN          No match
#  4  Schwarzenegger’s multi-million dollar ‘robo-fu...  court, violation
#
#      risk_level  risk_code  text_relates_to_company  \
#  0     Low Risk          0                    False
#  1  Medium Risk          1                    False
#  2     Low Risk          0                    False
#  3     Low Risk          0                    False
#  4  Medium Risk          1                    False
#
#     nlp_analysis_relates_to_company
#  0                            False
#  1                            False
#  2                            False
#  3                            False
#  4                            False  )

# %%
# Define a set of high-risk keywords to search for in the extracted_text
high_risk_keywords = [
    "fraud", "corruption", "scam", "lawsuit", "illegal", "sanction",
    "investigation", "criminal", "violation", "money laundering", "bribe"
]

# Function to check for high-risk keywords in the text
def check_high_risk_keywords(text):
    if pd.isna(text):
        return False
    text_lower = text.lower()
    return any(keyword in text_lower for keyword in high_risk_keywords)

# Apply the risk check to the dataset
data['contains_high_risk_keywords'] = data['extracted_text'].apply(check_high_risk_keywords)

# Count how many rows contain high-risk keywords and display examples
high_risk_counts = data['contains_high_risk_keywords'].value_counts()
high_risk_examples = data[data['contains_high_risk_keywords'] == True].head(5)

# Check for duplicate company entries
duplicate_companies = data['company'].duplicated().sum()

# Analyze the sources (URLs) for potential risks (e.g., suspicious domains)
data['suspicious_url'] = data['url'].str.contains(r'(offshore|leaks|scam|fraud)', case=False, na=False)

# Summarize suspicious URLs
suspicious_url_count = data['suspicious_url'].sum()
suspicious_url_examples = data[data['suspicious_url'] == True].head(5)

high_risk_counts, high_risk_examples, duplicate_companies, suspicious_url_count, suspicious_url_examples
# Out:
# <ipython-input-4-34665029e8dd>:25: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   data['suspicious_url'] = data['url'].str.contains(r'(offshore|leaks|scam|fraud)', case=False, na=False)
# (contains_high_risk_keywords
#  False    466
#  True      34
#  Name: count, dtype: int64,
#                                       company  \
#  2       FORTUNEMAKER INVESTMENTS CORPORATION
#  4       FORTUNEMAKER INVESTMENTS CORPORATION
#  21  TIANSHENG INDUSTRY AND TRADING CO., LTD.
#  85                      8808 HOLDING LIMITED
#  87                      8808 HOLDING LIMITED
#
#                                                    url  \
#  2   https://foe.org/blog/2014-04-the-schwarzenegge...
#  4   https://www.globalwitness.org/en/archive/schwa...
#  21      https://offshoreleaks.icij.org/nodes/10000001
#  85  https://www.scc.virginia.gov/pages/Application...
#  87                        https://www.man.com/contact
#
#                                         extracted_text  \
#  2   The Schwarzenegger dilemma:Years of investing ...
#  4   Schwarzenegger’s multi-million dollar ‘robo-fu...
#  21  TIANSHENG INDUSTRY AND TRADING CO., | ICIJ Off...
#  85  Virginia SCC - Application Forms Home Financia...
#  87  Contact | Man Group You are now exiting our we...
#
#               related_keywords   risk_level  risk_code  \
#  2                    No match     Low Risk          0
#  4            court, violation  Medium Risk          1
#  21  corruption, investigation    High Risk          2
#  85        investigation, debt  Medium Risk          1
#  87       court, investigation  Medium Risk          1
#
#      text_relates_to_company  nlp_analysis_relates_to_company  \
#  2                     False                            False
#  4                     False                            False
#  21                    False                            False
#  85                    False                            False
#  87                    False                            False
#
#      contains_high_risk_keywords
#  2                          True
#  4                          True
#  21                         True
#  85                         True
#  87                         True  ,
#  450,
#  4,
#                                        company  \
#  21   TIANSHENG INDUSTRY AND TRADING CO., LTD.
#  299                Alvear Investments Limited
#  313               TOPLINE INVESTMENTS LIMITED
#  431                      CORAL SEA GROUP LTD.
#
#                                                 url  \
#  21   https://offshoreleaks.icij.org/nodes/10000001
#  299  https://offshoreleaks.icij.org/nodes/12204276
#  313  https://offshoreleaks.icij.org/nodes/10000032
#  431    https://offshoreleaks.icij.org/nodes/130560
#
#                                          extracted_text  \
#  21   TIANSHENG INDUSTRY AND TRADING CO., | ICIJ Off...
#  299  STEPHEN KAMALIA MIKHAIL | ICIJ Offshore Leaks ...
#  313  TOPLINE INVESTMENTS LIMITED | ICIJ Offshore Le...
#  431  CORAL SEA GROUP LIMITED | ICIJ Offshore Leaks ...
#
#                related_keywords risk_level  risk_code  text_relates_to_company  \
#  21   corruption, investigation  High Risk          2                    False
#  299  corruption, investigation  High Risk          2                     True
#  313  corruption, investigation  High Risk          2                     True
#  431  corruption, investigation  High Risk          2                    False
#
#       nlp_analysis_relates_to_company  contains_high_risk_keywords  \
#  21                             False                         True
#  299                             True                         True
#  313                             True                         True
#  431                            False                         True
#
#       suspicious_url
#  21             True
#  299            True
#  313            True
#  431            True  )

# %%
# Define high-risk keywords
high_risk_keywords = [
    "fraud", "corruption", "scam", "lawsuit", "illegal", "sanction",
    "investigation", "criminal", "violation", "money laundering", "bribe"
]

# Function to check for high-risk keywords in the text
def check_high_risk_keywords(text):
    if pd.isna(text):
        return False
    text_lower = text.lower()
    return any(keyword in text_lower for keyword in high_risk_keywords)

# Apply the function to create the column
data['contains_high_risk_keywords'] = data['extracted_text'].apply(check_high_risk_keywords)

# %%
print(data.columns)
# Out:
# Index(['company', 'url', 'extracted_text', 'related_keywords', 'risk_level',
#        'risk_code', 'text_relates_to_company',
#        'nlp_analysis_relates_to_company', 'contains_high_risk_keywords',
#        'suspicious_url'],
#       dtype='object')

# %%
high_risk_entries = data[data['contains_high_risk_keywords'] | data['suspicious_url']]
from IPython.display import display
display(high_risk_entries)
# Out:
#                                           company  \
# 2            FORTUNEMAKER INVESTMENTS CORPORATION
# 4            FORTUNEMAKER INVESTMENTS CORPORATION
# 21       TIANSHENG INDUSTRY AND TRADING CO., LTD.
# 85                           8808 HOLDING LIMITED
# 87                           8808 HOLDING LIMITED
# 126          Wide International Trading Co., Ltd.
# 133                    JIE LUN INVESTMENT LIMITED
# 158                        FORTUNE PALACE LIMITED
# 191                  LAKE STREET INVESTMENTS LTD.
# 196                  LAKE STREET INVESTMENTS LTD.
# 198                  LAKE STREET INVESTMENTS LTD.
# 203          SUNNY TREASURE INTERNATIONAL LIMITED
# 219                                CHEM D-T Corp.
# 223                                   GIT CO INC.
# 225                                   GIT CO INC.
# 228                                   GIT CO INC.
# 233  NINGBO RAPID INTERNATIONAL TRADING CO., LTD.
# 240                  EURO INVESTMENT CAPITAL INC.
# 241                  EURO INVESTMENT CAPITAL INC.
# 242                  EURO INVESTMENT CAPITAL INC.
# 249                  EURO INVESTMENT CAPITAL INC.
# 273                            Aegis Infocom Inc.
# 279                            Aegis Infocom Inc.
# 299                    Alvear Investments Limited
# 313                   TOPLINE INVESTMENTS LIMITED
# 354                      TETRA INTERNATIONAL LTD.
# 355                      TETRA INTERNATIONAL LTD.
# 359                      TETRA INTERNATIONAL LTD.
# 371                       SADDLEVILLE CORPORATION
# 376                       SADDLEVILLE CORPORATION
# 408                              LONSDALE LIMITED
# 431                          CORAL SEA GROUP LTD.
# 456                    DAFORD INTERNATIONAL CORP.
# 459                    DAFORD INTERNATIONAL CORP.
#
#                                                    url  \
# 2    https://foe.org/blog/2014-04-the-schwarzenegge...
# 4    https://www.globalwitness.org/en/archive/schwa...
# 21       https://offshoreleaks.icij.org/nodes/10000001
# 85   https://www.scc.virginia.gov/pages/Application...
# 87                         https://www.man.com/contact
# 126  https://home.treasury.gov/news/press-releases/...
# 133            https://en.zhonglun.com/team/xujie.html
# 158  https://fortune.com/2011/07/28/inside-pfizers-...
# 191  https://www.linkedin.com/company/lake-street-c...
# 196  https://www.treasury.gov/auctions/treasury/rp/...
# 198                        https://www.janestreet.com/
# 203  https://www.sunnysideofthedoc.com/palmares/off...
# 219                           https://www.hitachi.com/
# 223  https://stackoverflow.com/questions/29007821/g...
# 225               https://en.wikipedia.org/wiki/GitHub
# 228                       https://www.gitguardian.com/
# 233  https://home.treasury.gov/news/press-releases/...
# 240                       https://www.baincapital.com/
# 241                            https://www.apollo.com/
# 242    https://www.schroders.com/en/global/individual/
# 249            https://www.blackrock.com/us/individual
# 273  https://www.5paisa.com/stocks/aegislog-share-p...
# 279  https://infocom2018.ieee-infocom.org/program/a...
# 299      https://offshoreleaks.icij.org/nodes/12204276
# 313      https://offshoreleaks.icij.org/nodes/10000032
# 354                      https://www.msiworldwide.com/
# 355                          https://www.tetrasoc.com/
# 359                https://intdev.tetratecheurope.com/
# 371  https://www.har.com/homedetail/19127-saddlevil...
# 376  https://www.woodlandsonline.com/npps/story.cfm...
# 408  https://www.fca.org.uk/news/news-stories/lonsd...
# 431        https://offshoreleaks.icij.org/nodes/130560
# 456                               https://www.rti.org/
# 459     https://uk.linkedin.com/company/globalgroupltd
#
#                                         extracted_text  \
# 2    The Schwarzenegger dilemma:Years of investing ...
# 4    Schwarzenegger’s multi-million dollar ‘robo-fu...
# 21   TIANSHENG INDUSTRY AND TRADING CO., | ICIJ Off...
# 85   Virginia SCC - Application Forms Home Financia...
# 87   Contact | Man Group You are now exiting our we...
# 126  Treasury Targets Large Iranian Military Financ...
# 133  ﻿ The official website of Zhong Lun Law Firm J...
# 158  Inside Pfizer’s palace coup | Fortune Home Pag...
# 191  Lake Street Capital Markets, LLC | LinkedIn Sk...
# 196  US Dept of the Treasury Seized Real Property A...
# 198  Home :: Jane Street This site uses cookies to ...
# 203  Official Selection #SSD23 - Sunny Side of the ...
# 219  Hitachi Global Skip to main content Region / L...
# 223  git checkout all the files - Stack Overflow Co...
# 225  GitHub - Wikipedia Jump to content From Wikipe...
# 228  GitGuardian: Git Security Scanning & Secrets D...
# 233  Treasury Targets Sanctions Evasion Network Mov...
# 240  Bain Capital Sorry, you need to enable JavaScr...
# 241  Home | Apollo Global Management General Public...
# 242  Schroders Slide 1 of 5 Prev Next Meet our new ...
# 249  Investment Management & Financial Services | B...
# 273  Aegis Logistics Share Price Today: Live Aegis ...
# 279  Accepted Paper List [Main Conference] | IEEE I...
# 299  STEPHEN KAMALIA MIKHAIL | ICIJ Offshore Leaks ...
# 313  TOPLINE INVESTMENTS LIMITED | ICIJ Offshore Le...
# 354  Home - MSI Skip to content Menu Facebook Twitt...
# 355  Law Enforcement Equipment Suppliers - Tetra Sc...
# 359  Home – intdevtetratecheurope.com Complex world...
# 371  19127 Saddleville Mills Ln, Houston, TX 77433 ...
# 376  WANTED: Suspect responsible for Continuous Sex...
# 408  Lonsdale Insurance Brokers Limited enters liqu...
# 431  CORAL SEA GROUP LIMITED | ICIJ Offshore Leaks ...
# 456  RTI International | Research Institute Skip to...
# 459  Global Group | LinkedIn Skip to main content G...
#
#                                       related_keywords   risk_level  \
# 2                                             No match     Low Risk
# 4                                     court, violation  Medium Risk
# 21                           corruption, investigation    High Risk
# 85                                 investigation, debt  Medium Risk
# 87                                court, investigation  Medium Risk
# 126                                          sanctions    High Risk
# 133                           court, crime, litigation    High Risk
# 158                    court, investigation, violation  Medium Risk
# 191                                           No match     Low Risk
# 196                                              court  Medium Risk
# 198                                           No match     Low Risk
# 203                          corruption, investigation    High Risk
# 219                                           No match     Low Risk
# 223                                           No match     Low Risk
# 225  court, crime, investigation, sanctions, litiga...    High Risk
# 228                                investigation, debt  Medium Risk
# 233                                          sanctions    High Risk
# 240                                           No match     Low Risk
# 241                                           No match     Low Risk
# 242                                               debt  Medium Risk
# 249                                           No match     Low Risk
# 273                                investigation, debt  Medium Risk
# 279                                      investigation  Medium Risk
# 299                          corruption, investigation    High Risk
# 313                          corruption, investigation    High Risk
# 354                                  court, corruption    High Risk
# 355                               crime, investigation    High Risk
# 359                                         corruption    High Risk
# 371                                           No match     Low Risk
# 376                               crime, investigation    High Risk
# 408                                  court, insolvency  Medium Risk
# 431                          corruption, investigation    High Risk
# 456                               court, criminal case    High Risk
# 459                                              court  Medium Risk
#
#      risk_code  text_relates_to_company  nlp_analysis_relates_to_company  \
# 2            0                    False                            False
# 4            1                    False                            False
# 21           2                    False                            False
# 85           1                    False                            False
# 87           1                    False                            False
# 126          2                    False                            False
# 133          2                    False                            False
# 158          1                    False                            False
# 191          0                    False                            False
# 196          1                    False                            False
# 198          0                    False                            False
# 203          2                    False                            False
# 219          0                    False                            False
# 223          0                    False                            False
# 225          2                    False                            False
# 228          1                    False                            False
# 233          2                    False                            False
# 240          0                    False                            False
# 241          0                    False                            False
# 242          1                    False                            False
# 249          0                    False                            False
# 273          1                    False                            False
# 279          1                    False                            False
# 299          2                     True                             True
# 313          2                     True                             True
# 354          2                    False                            False
# 355          2                    False                            False
# 359          2                    False                            False
# 371          0                    False                            False
# 376          2                    False                            False
# 408          1                    False                            False
# 431          2                    False                            False
# 456          2                    False                            False
# 459          1                    False                            False
#
#      contains_high_risk_keywords  suspicious_url
# 2                           True           False
# 4                           True           False
# 21                          True            True
# 85                          True           False
# 87                          True           False
# 126                         True           False
# 133                         True           False
# 158                         True           False
# 191                         True           False
# 196                         True           False
# 198                         True           False
# 203                         True           False
# 219                         True           False
# 223                         True           False
# 225                         True           False
# 228                         True           False
# 233                         True           False
# 240                         True           False
# 241                         True           False
# 242                         True           False
# 249                         True           False
# 273                         True           False
# 279                         True           False
# 299                         True            True
# 313                         True            True
# 354                         True           False
# 355                         True           False
# 359                         True           False
# 371                         True           False
# 376                         True           False
# 408                         True           False
# 431                         True            True
# 456                         True           False
# 459                         True           False

# %%
# Display the high-risk entries in the Colab environment
high_risk_entries
# Out:
#                                           company  \
# 2            FORTUNEMAKER INVESTMENTS CORPORATION
# 4            FORTUNEMAKER INVESTMENTS CORPORATION
# 21       TIANSHENG INDUSTRY AND TRADING CO., LTD.
# 85                           8808 HOLDING LIMITED
# 87                           8808 HOLDING LIMITED
# 126          Wide International Trading Co., Ltd.
# 133                    JIE LUN INVESTMENT LIMITED
# 158                        FORTUNE PALACE LIMITED
# 191                  LAKE STREET INVESTMENTS LTD.
# 196                  LAKE STREET INVESTMENTS LTD.
# 198                  LAKE STREET INVESTMENTS LTD.
# 203          SUNNY TREASURE INTERNATIONAL LIMITED
# 219                                CHEM D-T Corp.
# 223                                   GIT CO INC.
# 225                                   GIT CO INC.
# 228                                   GIT CO INC.
# 233  NINGBO RAPID INTERNATIONAL TRADING CO., LTD.
# 240                  EURO INVESTMENT CAPITAL INC.
# 241                  EURO INVESTMENT CAPITAL INC.
# 242                  EURO INVESTMENT CAPITAL INC.
# 249                  EURO INVESTMENT CAPITAL INC.
# 273                            Aegis Infocom Inc.
# 279                            Aegis Infocom Inc.
# 299                    Alvear Investments Limited
# 313                   TOPLINE INVESTMENTS LIMITED
# 354                      TETRA INTERNATIONAL LTD.
# 355                      TETRA INTERNATIONAL LTD.
# 359                      TETRA INTERNATIONAL LTD.
# 371                       SADDLEVILLE CORPORATION
# 376                       SADDLEVILLE CORPORATION
# 408                              LONSDALE LIMITED
# 431                          CORAL SEA GROUP LTD.
# 456                    DAFORD INTERNATIONAL CORP.
# 459                    DAFORD INTERNATIONAL CORP.
#
#                                                    url  \
# 2    https://foe.org/blog/2014-04-the-schwarzenegge...
# 4    https://www.globalwitness.org/en/archive/schwa...
# 21       https://offshoreleaks.icij.org/nodes/10000001
# 85   https://www.scc.virginia.gov/pages/Application...
# 87                         https://www.man.com/contact
# 126  https://home.treasury.gov/news/press-releases/...
# 133            https://en.zhonglun.com/team/xujie.html
# 158  https://fortune.com/2011/07/28/inside-pfizers-...
# 191  https://www.linkedin.com/company/lake-street-c...
# 196  https://www.treasury.gov/auctions/treasury/rp/...
# 198                        https://www.janestreet.com/
# 203  https://www.sunnysideofthedoc.com/palmares/off...
# 219                           https://www.hitachi.com/
# 223  https://stackoverflow.com/questions/29007821/g...
# 225               https://en.wikipedia.org/wiki/GitHub
# 228                       https://www.gitguardian.com/
# 233  https://home.treasury.gov/news/press-releases/...
# 240                       https://www.baincapital.com/
# 241                            https://www.apollo.com/
# 242    https://www.schroders.com/en/global/individual/
# 249            https://www.blackrock.com/us/individual
# 273  https://www.5paisa.com/stocks/aegislog-share-p...
# 279  https://infocom2018.ieee-infocom.org/program/a...
# 299      https://offshoreleaks.icij.org/nodes/12204276
# 313      https://offshoreleaks.icij.org/nodes/10000032
# 354                      https://www.msiworldwide.com/
# 355                          https://www.tetrasoc.com/
# 359                https://intdev.tetratecheurope.com/
# 371  https://www.har.com/homedetail/19127-saddlevil...
# 376  https://www.woodlandsonline.com/npps/story.cfm...
# 408  https://www.fca.org.uk/news/news-stories/lonsd...
# 431        https://offshoreleaks.icij.org/nodes/130560
# 456                               https://www.rti.org/
# 459     https://uk.linkedin.com/company/globalgroupltd
#
#                                         extracted_text  \
# 2    The Schwarzenegger dilemma:Years of investing ...
# 4    Schwarzenegger’s multi-million dollar ‘robo-fu...
# 21   TIANSHENG INDUSTRY AND TRADING CO., | ICIJ Off...
# 85   Virginia SCC - Application Forms Home Financia...
# 87   Contact | Man Group You are now exiting our we...
# 126  Treasury Targets Large Iranian Military Financ...
# 133  ﻿ The official website of Zhong Lun Law Firm J...
# 158  Inside Pfizer’s palace coup | Fortune Home Pag...
# 191  Lake Street Capital Markets, LLC | LinkedIn Sk...
# 196  US Dept of the Treasury Seized Real Property A...
# 198  Home :: Jane Street This site uses cookies to ...
# 203  Official Selection #SSD23 - Sunny Side of the ...
# 219  Hitachi Global Skip to main content Region / L...
# 223  git checkout all the files - Stack Overflow Co...
# 225  GitHub - Wikipedia Jump to content From Wikipe...
# 228  GitGuardian: Git Security Scanning & Secrets D...
# 233  Treasury Targets Sanctions Evasion Network Mov...
# 240  Bain Capital Sorry, you need to enable JavaScr...
# 241  Home | Apollo Global Management General Public...
# 242  Schroders Slide 1 of 5 Prev Next Meet our new ...
# 249  Investment Management & Financial Services | B...
# 273  Aegis Logistics Share Price Today: Live Aegis ...
# 279  Accepted Paper List [Main Conference] | IEEE I...
# 299  STEPHEN KAMALIA MIKHAIL | ICIJ Offshore Leaks ...
# 313  TOPLINE INVESTMENTS LIMITED | ICIJ Offshore Le...
# 354  Home - MSI Skip to content Menu Facebook Twitt...
# 355  Law Enforcement Equipment Suppliers - Tetra Sc...
# 359  Home – intdevtetratecheurope.com Complex world...
# 371  19127 Saddleville Mills Ln, Houston, TX 77433 ...
# 376  WANTED: Suspect responsible for Continuous Sex...
# 408  Lonsdale Insurance Brokers Limited enters liqu...
# 431  CORAL SEA GROUP LIMITED | ICIJ Offshore Leaks ...
# 456  RTI International | Research Institute Skip to...
# 459  Global Group | LinkedIn Skip to main content G...
#
#                                       related_keywords   risk_level  \
# 2                                             No match     Low Risk
# 4                                     court, violation  Medium Risk
# 21                           corruption, investigation    High Risk
# 85                                 investigation, debt  Medium Risk
# 87                                court, investigation  Medium Risk
# 126                                          sanctions    High Risk
# 133                           court, crime, litigation    High Risk
# 158                    court, investigation, violation  Medium Risk
# 191                                           No match     Low Risk
# 196                                              court  Medium Risk
# 198                                           No match     Low Risk
# 203                          corruption, investigation    High Risk
# 219                                           No match     Low Risk
# 223                                           No match     Low Risk
# 225  court, crime, investigation, sanctions, litiga...    High Risk
# 228                                investigation, debt  Medium Risk
# 233                                          sanctions    High Risk
# 240                                           No match     Low Risk
# 241                                           No match     Low Risk
# 242                                               debt  Medium Risk
# 249                                           No match     Low Risk
# 273                                investigation, debt  Medium Risk
# 279                                      investigation  Medium Risk
# 299                          corruption, investigation    High Risk
# 313                          corruption, investigation    High Risk
# 354                                  court, corruption    High Risk
# 355                               crime, investigation    High Risk
# 359                                         corruption    High Risk
# 371                                           No match     Low Risk
# 376                               crime, investigation    High Risk
# 408                                  court, insolvency  Medium Risk
# 431                          corruption, investigation    High Risk
# 456                               court, criminal case    High Risk
# 459                                              court  Medium Risk
#
#      risk_code  text_relates_to_company  nlp_analysis_relates_to_company  \
# 2            0                    False                            False
# 4            1                    False                            False
# 21           2                    False                            False
# 85           1                    False                            False
# 87           1                    False                            False
# 126          2                    False                            False
# 133          2                    False                            False
# 158          1                    False                            False
# 191          0                    False                            False
# 196          1                    False                            False
# 198          0                    False                            False
# 203          2                    False                            False
# 219          0                    False                            False
# 223          0                    False                            False
# 225          2                    False                            False
# 228          1                    False                            False
# 233          2                    False                            False
# 240          0                    False                            False
# 241          0                    False                            False
# 242          1                    False                            False
# 249          0                    False                            False
# 273          1                    False                            False
# 279          1                    False                            False
# 299          2                     True                             True
# 313          2                     True                             True
# 354          2                    False                            False
# 355          2                    False                            False
# 359          2                    False                            False
# 371          0                    False                            False
# 376          2                    False                            False
# 408          1                    False                            False
# 431          2                    False                            False
# 456          2                    False                            False
# 459          1                    False                            False
#
#      contains_high_risk_keywords  suspicious_url
# 2                           True           False
# 4                           True           False
# 21                          True            True
# 85                          True           False
# 87                          True           False
# 126                         True           False
# 133                         True           False
# 158                         True           False
# 191                         True           False
# 196                         True           False
# 198                         True           False
# 203                         True           False
# 219                         True           False
# 223                         True           False
# 225                         True           False
# 228                         True           False
# 233                         True           False
# 240                         True           False
# 241                         True           False
# 242                         True           False
# 249                         True           False
# 273                         True           False
# 279                         True           False
# 299                         True            True
# 313                         True            True
# 354                         True           False
# 355                         True           False
# 359                         True           False
# 371                         True           False
# 376                         True           False
# 408                         True           False
# 431                         True            True
# 456                         True           False
# 459                         True           False

# %%
# Save the high-risk entries to a CSV file for download
high_risk_entries.to_csv('high_risk_entries.csv', index=False)

# Provide a download link for the CSV file
from google.colab import files
files.download('high_risk_entries.csv')

# %%
from textblob import TextBlob

# Function to perform sentiment analysis
def analyze_sentiment(text):
    if pd.isna(text) or not text.strip():
        return "Neutral"  # Treat missing or empty text as Neutral
    analysis = TextBlob(text)
    # Determine sentiment polarity: Positive (>0), Negative (<0), Neutral (=0)
    if analysis.sentiment.polarity > 0:
        return "Positive"
    elif analysis.sentiment.polarity < 0:
        return "Negative"
    else:
        return "Neutral"

# Apply sentiment analysis to the 'extracted_text' column
data['sentiment'] = data['extracted_text'].apply(analyze_sentiment)

# Count sentiment distribution and display examples for each sentiment
sentiment_counts = data['sentiment'].value_counts()
examples_positive = data[data['sentiment'] == "Positive"].head(5)
examples_negative = data[data['sentiment'] == "Negative"].head(5)
examples_neutral = data[data['sentiment'] == "Neutral"].head(5)

sentiment_counts, examples_positive, examples_negative, examples_neutral
# Out:
# (sentiment
#  Positive    348
#  Neutral     100
#  Negative     52
#  Name: count, dtype: int64,
#                                  company  \
#  0  FORTUNEMAKER INVESTMENTS CORPORATION
#  1  FORTUNEMAKER INVESTMENTS CORPORATION
#  2  FORTUNEMAKER INVESTMENTS CORPORATION
#  4  FORTUNEMAKER INVESTMENTS CORPORATION
#  5  FORTUNEMAKER INVESTMENTS CORPORATION
#
#                                                   url  \
#  0  https://www.forbes.com/sites/daveknox/2022/07/...
#  1                               https://fortune.com/
#  2  https://foe.org/blog/2014-04-the-schwarzenegge...
#  4  https://www.globalwitness.org/en/archive/schwa...
#  5  https://sku.is/patrick-schwarzenegger-talks-cp...
#
#                                        extracted_text  related_keywords  \
#  0  Why Brain Health Is Patrick Schwarzenegger’s L...          No match
#  1  Fortune - Fortune 500 Daily & Breaking Busines...              debt
#  2  The Schwarzenegger dilemma:Years of investing ...          No match
#  4  Schwarzenegger’s multi-million dollar ‘robo-fu...  court, violation
#  5  Patrick Schwarzenegger talks CPG Investing and...          No match
#
#      risk_level  risk_code  text_relates_to_company  \
#  0     Low Risk          0                    False
#  1  Medium Risk          1                    False
#  2     Low Risk          0                    False
#  4  Medium Risk          1                    False
#  5     Low Risk          0                    False
#
#     nlp_analysis_relates_to_company  contains_high_risk_keywords  \
#  0                            False                        False
#  1                            False                        False
#  2                            False                         True
#  4                            False                         True
#  5                            False                        False
#
#     suspicious_url sentiment
#  0           False  Positive
#  1           False  Positive
#  2           False  Positive
#  4           False  Positive
#  5           False  Positive  ,
#                                       company  \
#  19                        HOTFOCUS CO., LTD.
#  26  TIANSHENG INDUSTRY AND TRADING CO., LTD.
#  29  TIANSHENG INDUSTRY AND TRADING CO., LTD.
#  32                            AMARANDAN LTD.
#  46           SKY-BLUE GIFTS & TOYS CO., LTD.
#
#                                                    url  \
#  19                       https://www.focusatwill.com/
#  26  https://www.federalregister.gov/documents/2020...
#  29  https://corporate.target.com/getmedia/07f80eea...
#  32  https://www.facebook.com/msfindia.in/photos/a....
#  46  http://www.sky-blue.com.cn/en/product_d/id/104...
#
#                                         extracted_text related_keywords  \
#  19  Get A 4x Increase In Productivity By Listening...         No match
#  26  Federal Register :: Request Access The Federal...         No match
#  29                    Skipped due to non-text content              NaN
#  32  Log into Facebook Notice You must log in to co...         No match
#  46  Wooden Train Set 50PCS - SKY-BLUE Quality Toys...         No match
#
#     risk_level  risk_code  text_relates_to_company  \
#  19   Low Risk          0                    False
#  26   Low Risk          0                    False
#  29    No Risk          0                    False
#  32   Low Risk          0                    False
#  46   Low Risk          0                     True
#
#      nlp_analysis_relates_to_company  contains_high_risk_keywords  \
#  19                            False                        False
#  26                            False                        False
#  29                            False                        False
#  32                            False                        False
#  46                            False                        False
#
#      suspicious_url sentiment
#  19           False  Negative
#  26           False  Negative
#  29           False  Negative
#  32           False  Negative
#  46           False  Negative  ,
#                                   company  \
#  3   FORTUNEMAKER INVESTMENTS CORPORATION
#  6   FORTUNEMAKER INVESTMENTS CORPORATION
#  7   FORTUNEMAKER INVESTMENTS CORPORATION
#  8   FORTUNEMAKER INVESTMENTS CORPORATION
#  10                    HOTFOCUS CO., LTD.
#
#                                                    url  \
#  3   https://www.inc.com/jeff-haden/arnold-schwarze...
#  6   https://www.reddit.com/r/todayilearned/comment...
#  7   https://transparint.com/documents/Panama_Paper...
#  8   https://www.linkedin.com/in/arnold-schwarzenegger
#  10  https://hotfocus.manufacturer.globalsources.co...
#
#                                         extracted_text related_keywords  \
#  3                                                 NaN         No match
#  6                                                 NaN         No match
#  7                                                 NaN         No match
#  8                                                 NaN         No match
#  10  Request unsuccessful. Incapsula incident ID: 2...         No match
#
#     risk_level  risk_code  text_relates_to_company  \
#  3    Low Risk          0                    False
#  6    Low Risk          0                    False
#  7    Low Risk          0                    False
#  8    Low Risk          0                    False
#  10   Low Risk          0                    False
#
#      nlp_analysis_relates_to_company  contains_high_risk_keywords  \
#  3                             False                        False
#  6                             False                        False
#  7                             False                        False
#  8                             False                        False
#  10                            False                        False
#
#      suspicious_url sentiment
#  3            False   Neutral
#  6            False   Neutral
#  7            False   Neutral
#  8            False   Neutral
#  10           False   Neutral  )

# %% [markdown]
# Code to Analyze Domain Patterns

# %%
# Extract domain names from the URLs
data['domain'] = data['url'].str.extract(r'//([^/]+)')

# Analyze domain frequency for all records
domain_counts = data['domain'].value_counts()

# Analyze domain frequency for high-risk cases
high_risk_domains = data[data['contains_high_risk_keywords'] | data['suspicious_url']]
high_risk_domain_counts = high_risk_domains['domain'].value_counts()

# Combine overall and high-risk domain counts into a DataFrame
domain_analysis = pd.DataFrame({
    'Overall Count': domain_counts,
    'High-Risk Count': high_risk_domain_counts
}).fillna(0)

# Display the combined DataFrame
domain_analysis.head(10)  # Adjust the number of rows to display more results if needed
# Out:
#                             Overall Count  High-Risk Count
# domain
# 4scic.com                               2              0.0
# about.gitlab.com                        1              0.0
# actionfacilities.com                    1              0.0
# allianceflaxlinenhemp.eu                1              0.0
# angelikafilmcenter.com                  1              0.0
# apps.apple.com                          1              0.0
# apps3.web.maine.gov                     1              0.0
# bbs.fobshanghai.com                     3              0.0
# bonustrade.company                      1              0.0
# bonusworldtradelimited.com              1              0.0

# %% [markdown]
# Code to Save Results for Download

# %%
# Save the domain analysis to a CSV file
domain_analysis.to_csv('domain_analysis.csv')

# Provide a download link for the CSV file
from google.colab import files
files.download('domain_analysis.csv')

# %% [markdown]
# 5. Duplicate Management
# Investigate the 90 duplicate companies:
# Are duplicates the same entity, or do they represent different contexts?

# %%
# Group duplicates based on company name
duplicate_companies = data[data.duplicated(subset=['company'], keep=False)]

# Investigate duplicates: Count instances and unique contexts for each duplicate company
duplicate_summary = duplicate_companies.groupby('company').agg(
    Count=('company', 'size'),  # Total instances of the company
    UniqueURLs=('url', 'nunique'),  # Unique URLs associated with the company
    RiskLevels=('risk_level', 'nunique'),  # Count of distinct risk levels
    Keywords=('related_keywords', lambda x: list(set(x)))  # Unique keywords
).sort_values(by='Count', ascending=False)

# Display duplicate summary
duplicate_summary.head(10)  # Display the top 10 duplicate companies
# Out:
#                                               Count  UniqueURLs  RiskLevels  \
# company
# 8808 HOLDING LIMITED                             10          10           3
# PRESTIGE INTERNATIONAL CORP.                     10          10           3
# KENT DEVELOPMENT LIMITED                         10          10           1
# KIND INTERNATIONAL INC.                          10          10           2
# LAKE STREET INVESTMENTS LTD.                     10          10           2
# LONSDALE LIMITED                                 10          10           2
# MEIHO INTERNATIONAL CO., LTD.                    10          10           1
# NECY CONSULTANTS LIMITED                         10          10           2
# NEW IDEA LIMITED                                 10          10           2
# NINGBO RAPID INTERNATIONAL TRADING CO., LTD.     10          10           2
#
#                                                                                        Keywords
# company
# 8808 HOLDING LIMITED                          [court, investigation, investigation, debt, No...
# PRESTIGE INTERNATIONAL CORP.                                             [court, No match, nan]
# KENT DEVELOPMENT LIMITED                                                             [No match]
# KIND INTERNATIONAL INC.                                           [court, litigation, No match]
# LAKE STREET INVESTMENTS LTD.                                [litigation, court, debt, No match]
# LONSDALE LIMITED                                                  [No match, court, insolvency]
# MEIHO INTERNATIONAL CO., LTD.                                                        [No match]
# NECY CONSULTANTS LIMITED                                                      [court, No match]
# NEW IDEA LIMITED                                                [litigation, penalty, No match]
# NINGBO RAPID INTERNATIONAL TRADING CO., LTD.                              [sanctions, No match]

# %% [markdown]
# Save Results to a File

# %%
# Save the duplicate summary to a CSV file
duplicate_summary.to_csv('duplicate_companies_analysis.csv')

# Provide a download link
from google.colab import files
files.download('duplicate_companies_analysis.csv')

# %%
import requests

# Function to query the Google Knowledge Graph API
def get_google_knowledge_graph_data(company_name, api_key):
    url = "https://kgsearch.googleapis.com/v1/entities:search"
    params = {
        'query': company_name,
        'key': api_key,
        'limit': 1,  # Number of results to fetch
        'indent': True  # Format the response for readability
    }
    response = requests.get(url, params=params)
    if response.status_code == 200:
        return response.json()  # Return the API response
    else:
        return {"error": f"API request failed with status code {response.status_code}"}

# Example usage
api_key = "xxx"  # Replace with your API key
company_name = "Google"
data = get_google_knowledge_graph_data(company_name, api_key)
data
# Out:
# {'@context': {'goog': 'http://schema.googleapis.com/',
#   'resultScore': 'goog:resultScore',
#   'kg': 'http://g.co/kg',
#   'detailedDescription': 'goog:detailedDescription',
#   '@vocab': 'http://schema.org/',
#   'EntitySearchResult': 'goog:EntitySearchResult'},
#  '@type': 'ItemList',
#  'itemListElement': [{'result': {'image': {'url': 'https://en.m.wikipedia.org/wiki/File:Google_2015_logo.svg',
#      'contentUrl': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcSA6xeoqtQcudXUieRkMQgiB48BrQP5tZQ6K3wenlV7FNsccVWA'},
#     'description': 'IT corporation',
#     '@id': 'kg:/m/045c7b',
#     'detailedDescription': {'url': 'https://en.wikipedia.org/wiki/Google',
#      'articleBody': 'Google LLC is an American-based multinational corporation and technology company focusing on online advertising, search engine technology, cloud computing, computer software, quantum computing, e-commerce, consumer electronics, and artificial intelligence. ',
#      'license': 'https://en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License'},
#     'name': 'Google',
#     '@type': ['Corporation', 'Thing', 'Organization']},
#    '@type': 'EntitySearchResult',
#    'resultScore': 111266.0390625}]}

# %% [markdown]
# 1. Load the CSV File and Extract Company Names
# Here’s the code to load the CSV and extract the first 10 company names:

# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv('Offshore Leaks-entities.csv', low_memory=False)

# Extract the first 10 company names
company_names = df['name'][0:20].tolist()

# Display the extracted names
print("Company Names:", company_names)
# Out:
# Company Names: ['TIANSHENG INDUSTRY AND TRADING CO., LTD.', 'NINGBO SUNRISE ENTERPRISES UNITED CO., LTD.', 'HOTFOCUS CO., LTD.', 'SKY-BLUE GIFTS & TOYS CO., LTD.', 'FORTUNEMAKER INVESTMENTS CORPORATION', '8808 HOLDING LIMITED', 'KENT DEVELOPMENT LIMITED', 'BONUS TRADE LIMITED', 'AMARANDAN LTD.', 'NEW IDEA LIMITED', 'HUGH POWER LIMITED', 'ULTIMATE GROUP LIMITED', 'VICTORY GROUP LIMITED', 'CHARTER MARK LIMITED', 'Wide International Trading Co., Ltd.', 'HTSS ET CAPITAL LIMITED', 'JIE LUN INVESTMENT LIMITED', 'FORTUNE PALACE LIMITED', 'LAKE STREET INVESTMENTS LTD.', 'NINGBO RAPID INTERNATIONAL TRADING CO., LTD.']

# %% [markdown]
# 2. Query the Google Knowledge Graph API for Each Company
# Now, use the extracted names to query the API.

# %%
import requests

# Google Knowledge Graph API function
def get_google_knowledge_graph_data(company_name, api_key):
    url = "https://kgsearch.googleapis.com/v1/entities:search"
    params = {
        'query': company_name,
        'key': api_key,
        'limit': 1,  # Fetch only the top result
        'indent': True  # Pretty print the response
    }
    response = requests.get(url, params=params)
    if response.status_code == 200:
        return response.json()
    else:
        return {"error": f"API request failed with status code {response.status_code}"}

# API Key (replace with your own)
api_key = "xxx"

# Query the API for the first 10 company names
enriched_data = []
for company in company_names:
    result = get_google_knowledge_graph_data(company, api_key)
    enriched_data.append({
        "Company Name": company,
        "API Result": result
    })

# Display the results
for item in enriched_data:
    print(f"Company: {item['Company Name']}")
    print(f"Result: {item['API Result']}")
# Out:
# Company: TIANSHENG INDUSTRY AND TRADING CO., LTD.
# Result: {'@context': {'EntitySearchResult': 'goog:EntitySearchResult', '@vocab': 'http://schema.org/', 'kg': 'http://g.co/kg', 'detailedDescription': 'goog:detailedDescription', 'goog': 'http://schema.googleapis.com/', 'resultScore': 'goog:resultScore'}, '@type': 'ItemList', 'itemListElement': []}
# Company: NINGBO SUNRISE ENTERPRISES UNITED CO., LTD.
# Result: {'@context': {'kg': 'http://g.co/kg', 'goog': 'http://schema.googleapis.com/', 'resultScore': 'goog:resultScore', 'detailedDescription': 'goog:detailedDescription', '@vocab': 'http://schema.org/', 'EntitySearchResult': 'goog:EntitySearchResult'}, '@type': 'ItemList', 'itemListElement': []}
# Company: HOTFOCUS CO., LTD.
# Result: {'@context': {'detailedDescription': 'goog:detailedDescription', '@vocab': 'http://schema.org/', 'kg': 'http://g.co/kg', 'goog': 'http://schema.googleapis.com/', 'resultScore': 'goog:resultScore', 'EntitySearchResult': 'goog:EntitySearchResult'}, '@type': 'ItemList', 'itemListElement': []}
# Company: SKY-BLUE GIFTS & TOYS CO., LTD.
# Result: {'@context': {'detailedDescription': 'goog:detailedDescription', 'kg': 'http://g.co/kg', 'resultScore': 'goog:resultScore', '@vocab': 'http://schema.org/', 'EntitySearchResult': 'goog:EntitySearchResult', 'goog': 'http://schema.googleapis.com/'}, '@type': 'ItemList', 'itemListElement': [{'result': {'@type': ['Organization', 'Thing'], '@id': 'kg:/g/11jnchvw0b', 'name': 'Ningbo Sky Blue Gifts &amp; Toys Co., Ltd.'}, 'resultScore': 77, '@type': 'EntitySearchResult'}]}
# Company: FORTUNEMAKER INVESTMENTS CORPORATION
# Result: {'@context': {'kg': 'http://g.co/kg', 'goog': 'http://schema.googleapis.com/', 'resultScore': 'goog:resultScore', '@vocab': 'http://schema.org/', 'detailedDescription': 'goog:detailedDescription', 'EntitySearchResult': 'goog:EntitySearchResult'}, '@type': 'ItemList', 'itemListElement': []}
# Company: 8808 HOLDING LIMITED
# Result: {'@context': {'goog': 'http://schema.googleapis.com/', '@vocab': 'http://schema.org/', 'detailedDescription': 'goog:detailedDescription', 'resultScore': 'goog:resultScore', 'kg': 'http://g.co/kg', 'EntitySearchResult': 'goog:EntitySearchResult'}, '@type': 'ItemList', 'itemListElement': []}
# Company: KENT DEVELOPMENT LIMITED
# Result: {'@context': {'EntitySearchResult': 'goog:EntitySearchResult', 'detailedDescription': 'goog:detailedDescription', 'goog': 'http://schema.googleapis.com/', 'resultScore': 'goog:resultScore', 'kg': 'http://g.co/kg', '@vocab': 'http://schema.org/'}, '@type': 'ItemList', 'itemListElement': [{'resultScore': 1.159232497215271, '@type': 'EntitySearchResult', 'result': {'@id': 'kg:/m/0_d5g', '@type': ['Book', 'Thing'], 'name': 'Crime and Punishment', 'detailedDescription': {'url': 'https://en.wikipedia.org/wiki/Crime_and_Punishment', 'license': 'https://en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License', 'articleBody': 'Crime and Punishment is a novel by the Russian author Fyodor Dostoevsky. It was first published in the literary journal The Russian Messenger in twelve monthly installments during 1866. It was later published in a single volume. '}, 'image': {'url': 'https://fi.m.wikipedia.org/wiki/Tiedosto:Crime_and_Punishment-1.png', 'contentUrl': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQOTvLzQlJfdAMLmy1EyeJ-OKbL7fwOaXal-kESGejiBo2Mxp5o'}, 'description': 'Novel by Fyodor Dostoevsky'}}]}
# Company: BONUS TRADE LIMITED
# Result: {'@context': {'resultScore': 'goog:resultScore', 'kg': 'http://g.co/kg', 'EntitySearchResult': 'goog:EntitySearchResult', 'detailedDescription': 'goog:detailedDescription', 'goog': 'http://schema.googleapis.com/', '@vocab': 'http://schema.org/'}, '@type': 'ItemList', 'itemListElement': [{'resultScore': 1.281807899475098, 'result': {'name': 'Madden NFL 23', 'detailedDescription': {'articleBody': 'Madden NFL 23 is a 2022 American football video game developed by EA Tiburon and published by Electronic Arts. Based on the National Football League, it is an installment in the Madden NFL series and follows the release of Madden NFL 22.\n', 'url': 'https://en.wikipedia.org/wiki/Madden_NFL_23', 'license': 'https://en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License'}, 'description': 'Video game', '@type': ['VideoGame', 'Thing', 'SoftwareApplication'], '@id': 'kg:/g/11t2cgrccw'}, '@type': 'EntitySearchResult'}]}
# Company: AMARANDAN LTD.
# Result: {'@context': {'@vocab': 'http://schema.org/', 'EntitySearchResult': 'goog:EntitySearchResult', 'detailedDescription': 'goog:detailedDescription', 'goog': 'http://schema.googleapis.com/', 'kg': 'http://g.co/kg', 'resultScore': 'goog:resultScore'}, '@type': 'ItemList', 'itemListElement': []}
# Company: NEW IDEA LIMITED
# Result: {'@context': {'detailedDescription': 'goog:detailedDescription', 'resultScore': 'goog:resultScore', 'EntitySearchResult': 'goog:EntitySearchResult', 'goog': 'http://schema.googleapis.com/', 'kg': 'http://g.co/kg', '@vocab': 'http://schema.org/'}, '@type': 'ItemList', 'itemListElement': []}
# Company: HUGH POWER LIMITED
# Result: {'@context': {'kg': 'http://g.co/kg', 'detailedDescription': 'goog:detailedDescription', 'goog': 'http://schema.googleapis.com/', '@vocab': 'http://schema.org/', 'resultScore': 'goog:resultScore', 'EntitySearchResult': 'goog:EntitySearchResult'}, '@type': 'ItemList', 'itemListElement': []}
# Company: ULTIMATE GROUP LIMITED
# Result: {'@context': {'resultScore': 'goog:resultScore', '@vocab': 'http://schema.org/', 'goog': 'http://schema.googleapis.com/', 'kg': 'http://g.co/kg', 'detailedDescription': 'goog:detailedDescription', 'EntitySearchResult': 'goog:EntitySearchResult'}, '@type': 'ItemList', 'itemListElement': [{'result': {'name': 'Ultimate Group Limited', '@id': 'kg:/g/11fmp9hvsr', 'description': 'Company', '@type': ['Organization', 'Thing', 'Corporation']}, 'resultScore': 43, '@type': 'EntitySearchResult'}]}
# Company: VICTORY GROUP LIMITED
# Result: {'@context': {'resultScore': 'goog:resultScore', 'detailedDescription': 'goog:detailedDescription', 'EntitySearchResult': 'goog:EntitySearchResult', '@vocab': 'http://schema.org/', 'kg': 'http://g.co/kg', 'goog': 'http://schema.googleapis.com/'}, '@type': 'ItemList', 'itemListElement': [{'resultScore': 82.58770751953125, '@type': 'EntitySearchResult', 'result': {'name': 'Victory Group', 'description': 'Company', '@id': 'kg:/m/0cqkxxj', '@type': ['Corporation', 'Thing', 'Organization']}}]}
# Company: CHARTER MARK LIMITED
# Result: {'@context': {'goog': 'http://schema.googleapis.com/', '@vocab': 'http://schema.org/', 'EntitySearchResult': 'goog:EntitySearchResult', 'resultScore': 'goog:resultScore', 'kg': 'http://g.co/kg', 'detailedDescription': 'goog:detailedDescription'}, '@type': 'ItemList', 'itemListElement': []}
# Company: Wide International Trading Co., Ltd.
# Result: {'@context': {'EntitySearchResult': 'goog:EntitySearchResult', 'kg': 'http://g.co/kg', 'goog': 'http://schema.googleapis.com/', 'resultScore': 'goog:resultScore', 'detailedDescription': 'goog:detailedDescription', '@vocab': 'http://schema.org/'}, '@type': 'ItemList', 'itemListElement': [{'resultScore': 51.59745788574219, '@type': 'EntitySearchResult', 'result': {'@id': 'kg:/m/0klx_cq', '@type': ['Organization', 'Thing', 'Corporation'], 'name': 'JD.com', 'description': 'E-commerce company', 'detailedDescription': {'url': 'https://en.wikipedia.org/wiki/JD.com', 'articleBody': 'JD.com, Inc., also known as Jingdong, formerly called 360buy, is a Chinese e-commerce company headquartered in Beijing. It is one of the two massive B2C online retailers in China by transaction volume and revenue, and is a major competitor to Alibaba-run Tmall. ', 'license': 'https://en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License'}}}]}
# Company: HTSS ET CAPITAL LIMITED
# Result: {'@context': {'goog': 'http://schema.googleapis.com/', '@vocab': 'http://schema.org/', 'detailedDescription': 'goog:detailedDescription', 'resultScore': 'goog:resultScore', 'kg': 'http://g.co/kg', 'EntitySearchResult': 'goog:EntitySearchResult'}, '@type': 'ItemList', 'itemListElement': []}
# Company: JIE LUN INVESTMENT LIMITED
# Result: {'@context': {'goog': 'http://schema.googleapis.com/', 'EntitySearchResult': 'goog:EntitySearchResult', 'detailedDescription': 'goog:detailedDescription', 'kg': 'http://g.co/kg', '@vocab': 'http://schema.org/', 'resultScore': 'goog:resultScore'}, '@type': 'ItemList', 'itemListElement': []}
# Company: FORTUNE PALACE LIMITED
# Result: {'@context': {'@vocab': 'http://schema.org/', 'EntitySearchResult': 'goog:EntitySearchResult', 'resultScore': 'goog:resultScore', 'kg': 'http://g.co/kg', 'detailedDescription': 'goog:detailedDescription', 'goog': 'http://schema.googleapis.com/'}, '@type': 'ItemList', 'itemListElement': [{'resultScore': 25, '@type': 'EntitySearchResult', 'result': {'@type': ['Organization', 'Thing', 'Corporation'], 'name': "Lin's Fortune Palace Limited", '@id': 'kg:/g/11jgsxdqwv'}}]}
# Company: LAKE STREET INVESTMENTS LTD.
# Result: {'@context': {'goog': 'http://schema.googleapis.com/', '@vocab': 'http://schema.org/', 'detailedDescription': 'goog:detailedDescription', 'resultScore': 'goog:resultScore', 'kg': 'http://g.co/kg', 'EntitySearchResult': 'goog:EntitySearchResult'}, '@type': 'ItemList', 'itemListElement': []}
# Company: NINGBO RAPID INTERNATIONAL TRADING CO., LTD.
# Result: {'@context': {'EntitySearchResult': 'goog:EntitySearchResult', 'kg': 'http://g.co/kg', 'goog': 'http://schema.googleapis.com/', 'detailedDescription': 'goog:detailedDescription', 'resultScore': 'goog:resultScore', '@vocab': 'http://schema.org/'}, '@type': 'ItemList', 'itemListElement': []}

# %% [markdown]
# 3. Save Results to a File
# If you want to save the results for further analysis:

# %%
import json

# Save the enriched data to a JSON file
with open('enriched_results.json', 'w') as f:
    json.dump(enriched_data, f, indent=4)

# If needed, save to a CSV file (basic summary)
results_summary = pd.DataFrame({
    "Company Name": [item["Company Name"] for item in enriched_data],
    "API Result Summary": [str(item["API Result"])[:100] for item in enriched_data]  # Truncate long results
})
results_summary.to_csv('enriched_results.csv', index=False)

# Provide a download link in Colab
from google.colab import files
files.download('enriched_results.json')
files.download('enriched_results.csv')

# %% [markdown]
# **Updated Code with Google Knowledge Graph Integration**

# %%
from googleapiclient.discovery import build
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import csv
from requests.exceptions import RequestException, SSLError

# Set up your API keys
google_api_key = 'xxx'
google_cse_id = 'xxx'

# Load the CSV file to get the first 100 company names
df = pd.read_csv('Offshore Leaks-entities.csv', low_memory=False)
# company_names = df['name'].head(100).tolist()
company_names = df['name'][0:5].tolist()  # Slice from 1st to 10th company

# Keywords to search for
keywords = [
    "court", "criminal case", "accusation", "crime", "corruption", "penalty",
    "investigation", "insolvency", "debt", "violation", "arrested", "sanctions",
    "litigation", "shell company", "blackmail"
]

# Function to perform Google search and get the first page
def google_search(search_term, api_key, cse_id, num_pages=1):
    service = build("customsearch", "v1", developerKey=api_key)
    results = []
    for page in range(num_pages):
        start_index = page * 1 #10 + 1  # Pagination starts at 1, 11, 21, ...
        res = service.cse().list(q=search_term, cx=cse_id, start=start_index).execute()
        if 'items' in res:
            results.extend(res['items'])
        time.sleep(1)  # Avoid rate limits by adding a delay
    return results

# Function to fetch data from the Google Knowledge Graph API
def get_google_knowledge_graph_data(company_name, api_key):
    url = "https://kgsearch.googleapis.com/v1/entities:search"
    params = {
        'query': company_name,
        'key': api_key,
        'limit': 1,  # Fetch only the top result
        'indent': True  # Pretty print the response
    }
    response = requests.get(url, params=params)
    if response.status_code == 200:
        return response.json()
    else:
        return None

# Function to extract text from a URL
def extract_text_from_url(url):
    headers = {
        'User-Agent': 'Mozilla/5.0',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
        'Accept-Language': 'en-US,en;q=0.5'
    }
    try:
        response = requests.get(url, headers=headers, verify=False, timeout=10)
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')
            text = ' '.join(p.text for p in soup.find_all('p'))
            return text
        else:
            print(f"Failed to fetch {url} with status code {response.status_code}")
            return ""
    except SSLError as e:
        print(f"SSL Error when accessing {url}: {e}")
        return ""
    except RequestException as e:
        print(f"Request failed for {url}: {e}")
        return ""

# Function to check if text contains any keywords
def contains_keywords(text, keywords):
    matched_keywords = [kw for kw in keywords if kw.lower() in text.lower()]
    return ", ".join(matched_keywords) if matched_keywords else "No match"

# Risk classification function
def classify_risk(related_keywords):
    if any(keyword in related_keywords.lower() for keyword in ["sanctions", "criminal", "crime", "corruption", "shell company"]):
        return "High Risk", 2
    elif related_keywords != "No match" and related_keywords != "No text extracted.":
        return "Medium Risk", 1
    else:
        return "Low Risk", 0

# Main process
data = pd.DataFrame(columns=[
    'company', 'url', 'extracted_text', 'related_keywords',
    'risk_level', 'risk_code', 'knowledge_graph_info'
])

for company_name in company_names:
    # Google Search
    results = google_search(company_name, google_api_key, google_cse_id, num_pages=1)
    for result in results:
        link = result.get('link')
        extracted_text = extract_text_from_url(link)
        related_keywords = contains_keywords(extracted_text, keywords)

        # Determine risk level and risk code
        risk_level, risk_code = classify_risk(related_keywords)

        # Fetch Knowledge Graph Data
        kg_data = get_google_knowledge_graph_data(company_name, google_api_key)
        kg_summary = (
            kg_data['itemListElement'][0]['result'].get('detailedDescription', {}).get('articleBody', 'N/A')
            if kg_data and 'itemListElement' in kg_data and len(kg_data['itemListElement']) > 0
            else "N/A"
        )

        # Create a new row and append it to the main DataFrame
        new_row = pd.DataFrame({
            'company': [company_name],
            'url': [link],
            'extracted_text': [extracted_text],
            'related_keywords': [related_keywords],
            'risk_level': [risk_level],
            'risk_code': [risk_code],
            'knowledge_graph_info': [kg_summary]
        })
        data = pd.concat([data, new_row], ignore_index=True)

        # Delay to avoid rate limits
        time.sleep(1)

# Save the results to a CSV file
data.to_csv('100_company_analysis_with_kg_results.csv', index=False, escapechar='\\', quoting=csv.QUOTE_MINIMAL)

print("Analysis complete. Results saved to '100_company_analysis_with_kg_results.csv'.")
# Out:
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'offshoreleaks.icij.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'tsheng-trade.en.made-in-china.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.echemi.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Failed to fetch https://www.echemi.com/shop-us20211025100945397/index.html with status code 403
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'allianceflaxlinenhemp.eu'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bbs.fobshanghai.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'gztsconstruction.en.made-in-china.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.chanchao.com.tw'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.federalregister.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'unblock.federalregister.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'corporate.target.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bbs.naccscenter.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'offshoreleaks.icij.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'transparint.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Failed to fetch https://transparint.com/documents/Panama_Papers_Entity_Names_List_2.txt with status code 406
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.thelancet.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Failed to fetch https://www.thelancet.com/cms/10.1016/S2666-5247(22)00387-1/attachment/f5d96b72-ad53-4d60-8c94-6cb3d89776ab/mmc6.xlsx with status code 403
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.sec.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Failed to fetch https://www.sec.gov/Archives/edgar/data/1780731/000121390023040481/f20f2022_sunrisenew.htm with status code 403
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.trade.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'iga.in.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.one-line.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.federalregister.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'unblock.federalregister.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www2.fmc.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hotfocus.manufacturer.globalsources.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.linkedin.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hotfocusinc.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Failed to fetch https://hotfocusinc.com/ with status code 406
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.indeed.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Failed to fetch https://www.indeed.com/cmp/Hot-Focus/reviews with status code 403
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.importinfo.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bbs.fobshanghai.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.faire.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Failed to fetch https://www.faire.com/brand/b_9y45lmodfz with status code 403
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'cn.linkedin.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sofineunion.en.alibaba.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'beyondthebarreusa.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.abyy.com.cn'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bskytoys.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'd.otto.de'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sourcing.hktdc.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'creativetoysandgifts.en.made-in-china.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sourcing.hktdc.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.amazon.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'foe.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.globalwitness.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'news.mongabay.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sku.is'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.linkedin.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.reddit.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Failed to fetch https://www.reddit.com/r/TikTokCringe/comments/16r2k8n/how_much_of_drew_barrymores_fortune_comes_from/ with status code 403
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.inc.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Failed to fetch https://www.inc.com/jeff-haden/arnold-schwarzenegger-just-gave-perfect-reason-to-keep-your-full-time-job-while-starting-your-own-business.html with status code 403
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.forbes.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'fortune.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'karagoldin.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Analysis complete. Results saved to '100_company_analysis_with_kg_results.csv'.
