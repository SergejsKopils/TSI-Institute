# %% [markdown]
# <a href="https://colab.research.google.com/github/NataKrj/AI-project-2024/blob/main/web_scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google-search-results
# !pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: google-search-results in /usr/local/lib/python3.10/dist-packages (2.4.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from google-search-results) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->google-search-results) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->google-search-results) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->google-search-results) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->google-search-results) (2024.8.30)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.8.30)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.6)

# %%
import csv
import os
import requests
from bs4 import BeautifulSoup
import urllib.parse
import time
import pandas as pd

# Load the CSV file
file_path = 'nodes-entities.csv'
df = pd.read_csv(file_path, usecols=['name'])
companies = df['name'].dropna().unique()[:10]  # Limit to first 10 companies

# List of word combinations to search with each company
keywords = [
    "court", "criminal case", "accusation", "crime", "corruption", "penalty", "investigation",
    "insolvency", "debt", "violation", "arrested", "sanctions", "litigation", "shell company", "blackmail"
]

# Setting up directories
output_dir = "output"
links_file = os.path.join(output_dir, "matched_links.csv")
os.makedirs(output_dir, exist_ok=True)

def duckduckgo_search(query):
    query = urllib.parse.quote_plus(query)
    url = f"https://html.duckduckgo.com/html/?q={query}"
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"}
    try:
        response = requests.get(url, headers=headers, timeout=10)
        response.raise_for_status()
        return response.text
    except requests.RequestException as e:
        print(f"Error fetching results for query: {query}, Error: {e}")
        return None

def parse_links_duckduckgo(html):
    soup = BeautifulSoup(html, 'html.parser')
    links = []
    for link in soup.find_all('a', class_='result__a', href=True):
        links.append(link['href'])
    return links

def search_company(company, keyword):
    query = f"{company} {keyword}"
    print(f"Searching for: {query}")
    html = duckduckgo_search(query)
    if html:
        links = parse_links_duckduckgo(html)
        if links:
            return links[0]  # Return the first link found
    return "No relevant link found"

def main():
    # Prepare CSV file for storing matched links
    with open(links_file, mode='w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerow(["Company", "Keyword", "Source"])

        # Iterate through each company and keyword
        for company in companies:
            for keyword in keywords:
                try:
                    # Search and collect the first result link
                    source = search_company(company, keyword)
                    writer.writerow([company, keyword, source])
                    time.sleep(3)  # Increase sleep time to prevent blocking
                except Exception as e:
                    print(f"Error searching for {company} with keyword {keyword}: {e}")

if __name__ == "__main__":
    main()
# Out:
# Searching for: TIANSHENG INDUSTRY AND TRADING CO., LTD. court
# Searching for: TIANSHENG INDUSTRY AND TRADING CO., LTD. criminal case
# Searching for: TIANSHENG INDUSTRY AND TRADING CO., LTD. accusation
# Searching for: TIANSHENG INDUSTRY AND TRADING CO., LTD. crime
# Searching for: TIANSHENG INDUSTRY AND TRADING CO., LTD. corruption
# Searching for: TIANSHENG INDUSTRY AND TRADING CO., LTD. penalty
# Searching for: TIANSHENG INDUSTRY AND TRADING CO., LTD. investigation
# Searching for: TIANSHENG INDUSTRY AND TRADING CO., LTD. insolvency
# Searching for: TIANSHENG INDUSTRY AND TRADING CO., LTD. debt
# Searching for: TIANSHENG INDUSTRY AND TRADING CO., LTD. violation
# Searching for: TIANSHENG INDUSTRY AND TRADING CO., LTD. arrested
# Searching for: TIANSHENG INDUSTRY AND TRADING CO., LTD. sanctions
# Searching for: TIANSHENG INDUSTRY AND TRADING CO., LTD. litigation
# Searching for: TIANSHENG INDUSTRY AND TRADING CO., LTD. shell company
# Searching for: TIANSHENG INDUSTRY AND TRADING CO., LTD. blackmail
# Searching for: NINGBO SUNRISE ENTERPRISES UNITED CO., LTD. court
# Searching for: NINGBO SUNRISE ENTERPRISES UNITED CO., LTD. criminal case
# Searching for: NINGBO SUNRISE ENTERPRISES UNITED CO., LTD. accusation
# Searching for: NINGBO SUNRISE ENTERPRISES UNITED CO., LTD. crime
# Searching for: NINGBO SUNRISE ENTERPRISES UNITED CO., LTD. corruption
# Searching for: NINGBO SUNRISE ENTERPRISES UNITED CO., LTD. penalty
# Searching for: NINGBO SUNRISE ENTERPRISES UNITED CO., LTD. investigation
# Searching for: NINGBO SUNRISE ENTERPRISES UNITED CO., LTD. insolvency
# Searching for: NINGBO SUNRISE ENTERPRISES UNITED CO., LTD. debt
# Searching for: NINGBO SUNRISE ENTERPRISES UNITED CO., LTD. violation
# Searching for: NINGBO SUNRISE ENTERPRISES UNITED CO., LTD. arrested
# Searching for: NINGBO SUNRISE ENTERPRISES UNITED CO., LTD. sanctions
# Searching for: NINGBO SUNRISE ENTERPRISES UNITED CO., LTD. litigation
# Searching for: NINGBO SUNRISE ENTERPRISES UNITED CO., LTD. shell company
# Searching for: NINGBO SUNRISE ENTERPRISES UNITED CO., LTD. blackmail
# Searching for: HOTFOCUS CO., LTD. court
# Searching for: HOTFOCUS CO., LTD. criminal case
# Searching for: HOTFOCUS CO., LTD. accusation
# Searching for: HOTFOCUS CO., LTD. crime
# Searching for: HOTFOCUS CO., LTD. corruption
# Searching for: HOTFOCUS CO., LTD. penalty
# Searching for: HOTFOCUS CO., LTD. investigation
# Searching for: HOTFOCUS CO., LTD. insolvency
# Searching for: HOTFOCUS CO., LTD. debt
# Searching for: HOTFOCUS CO., LTD. violation
# Searching for: HOTFOCUS CO., LTD. arrested
# Searching for: HOTFOCUS CO., LTD. sanctions
# Searching for: HOTFOCUS CO., LTD. litigation
# Searching for: HOTFOCUS CO., LTD. shell company
# Searching for: HOTFOCUS CO., LTD. blackmail
# Searching for: SKY-BLUE GIFTS & TOYS CO., LTD. court
# Searching for: SKY-BLUE GIFTS & TOYS CO., LTD. criminal case
# Searching for: SKY-BLUE GIFTS & TOYS CO., LTD. accusation
# Searching for: SKY-BLUE GIFTS & TOYS CO., LTD. crime
# Searching for: SKY-BLUE GIFTS & TOYS CO., LTD. corruption
# Searching for: SKY-BLUE GIFTS & TOYS CO., LTD. penalty
# Searching for: SKY-BLUE GIFTS & TOYS CO., LTD. investigation
# Error fetching results for query: SKY-BLUE+GIFTS+%26+TOYS+CO.%2C+LTD.+investigation, Error: 403 Client Error: Forbidden for url: https://html.duckduckgo.com/html/?q=SKY-BLUE+GIFTS+%26+TOYS+CO.%2C+LTD.+investigation
# Searching for: SKY-BLUE GIFTS & TOYS CO., LTD. insolvency
# Error fetching results for query: SKY-BLUE+GIFTS+%26+TOYS+CO.%2C+LTD.+insolvency, Error: 403 Client Error: Forbidden for url: https://html.duckduckgo.com/html/?q=SKY-BLUE+GIFTS+%26+TOYS+CO.%2C+LTD.+insolvency
# Searching for: SKY-BLUE GIFTS & TOYS CO., LTD. debt
# Error fetching results for query: SKY-BLUE+GIFTS+%26+TOYS+CO.%2C+LTD.+debt, Error: 403 Client Error: Forbidden for url: https://html.duckduckgo.com/html/?q=SKY-BLUE+GIFTS+%26+TOYS+CO.%2C+LTD.+debt
# Searching for: SKY-BLUE GIFTS & TOYS CO., LTD. violation
# Error fetching results for query: SKY-BLUE+GIFTS+%26+TOYS+CO.%2C+LTD.+violation, Error: 403 Client Error: Forbidden for url: https://html.duckduckgo.com/html/?q=SKY-BLUE+GIFTS+%26+TOYS+CO.%2C+LTD.+violation
# Searching for: SKY-BLUE GIFTS & TOYS CO., LTD. arrested
# Error fetching results for query: SKY-BLUE+GIFTS+%26+TOYS+CO.%2C+LTD.+arrested, Error: 403 Client Error: Forbidden for url: https://html.duckduckgo.com/html/?q=SKY-BLUE+GIFTS+%26+TOYS+CO.%2C+LTD.+arrested
# Searching for: SKY-BLUE GIFTS & TOYS CO., LTD. sanctions
# Error fetching results for query: SKY-BLUE+GIFTS+%26+TOYS+CO.%2C+LTD.+sanctions, Error: 403 Client Error: Forbidden for url: https://html.duckduckgo.com/html/?q=SKY-BLUE+GIFTS+%26+TOYS+CO.%2C+LTD.+sanctions
# Searching for: SKY-BLUE GIFTS & TOYS CO., LTD. litigation
# Error fetching results for query: SKY-BLUE+GIFTS+%26+TOYS+CO.%2C+LTD.+litigation, Error: 403 Client Error: Forbidden for url: https://html.duckduckgo.com/html/?q=SKY-BLUE+GIFTS+%26+TOYS+CO.%2C+LTD.+litigation
# Searching for: SKY-BLUE GIFTS & TOYS CO., LTD. shell company
# Error fetching results for query: SKY-BLUE+GIFTS+%26+TOYS+CO.%2C+LTD.+shell+company, Error: 403 Client Error: Forbidden for url: https://html.duckduckgo.com/html/?q=SKY-BLUE+GIFTS+%26+TOYS+CO.%2C+LTD.+shell+company
# Searching for: SKY-BLUE GIFTS & TOYS CO., LTD. blackmail
# Error fetching results for query: SKY-BLUE+GIFTS+%26+TOYS+CO.%2C+LTD.+blackmail, Error: 403 Client Error: Forbidden for url: https://html.duckduckgo.com/html/?q=SKY-BLUE+GIFTS+%26+TOYS+CO.%2C+LTD.+blackmail
# Searching for: FORTUNEMAKER INVESTMENTS CORPORATION court
# Error fetching results for query: FORTUNEMAKER+INVESTMENTS+CORPORATION+court, Error: 403 Client Error: Forbidden for url: https://html.duckduckgo.com/html/?q=FORTUNEMAKER+INVESTMENTS+CORPORATION+court
# Searching for: FORTUNEMAKER INVESTMENTS CORPORATION criminal case
# Error fetching results for query: FORTUNEMAKER+INVESTMENTS+CORPORATION+criminal+case, Error: 403 Client Error: Forbidden for url: https://html.duckduckgo.com/html/?q=FORTUNEMAKER+INVESTMENTS+CORPORATION+criminal+case
# Searching for: FORTUNEMAKER INVESTMENTS CORPORATION accusation
# Error fetching results for query: FORTUNEMAKER+INVESTMENTS+CORPORATION+accusation, Error: 403 Client Error: Forbidden for url: https://html.duckduckgo.com/html/?q=FORTUNEMAKER+INVESTMENTS+CORPORATION+accusation
# Searching for: FORTUNEMAKER INVESTMENTS CORPORATION crime
# Error fetching results for query: FORTUNEMAKER+INVESTMENTS+CORPORATION+crime, Error: 403 Client Error: Forbidden for url: https://html.duckduckgo.com/html/?q=FORTUNEMAKER+INVESTMENTS+CORPORATION+crime
# Searching for: FORTUNEMAKER INVESTMENTS CORPORATION corruption
# Error fetching results for query: FORTUNEMAKER+INVESTMENTS+CORPORATION+corruption, Error: 403 Client Error: Forbidden for url: https://html.duckduckgo.com/html/?q=FORTUNEMAKER+INVESTMENTS+CORPORATION+corruption
# Searching for: FORTUNEMAKER INVESTMENTS CORPORATION penalty
# Error fetching results for query: FORTUNEMAKER+INVESTMENTS+CORPORATION+penalty, Error: 403 Client Error: Forbidden for url: https://html.duckduckgo.com/html/?q=FORTUNEMAKER+INVESTMENTS+CORPORATION+penalty
# Searching for: FORTUNEMAKER INVESTMENTS CORPORATION investigation
# Error fetching results for query: FORTUNEMAKER+INVESTMENTS+CORPORATION+investigation, Error: 403 Client Error: Forbidden for url: https://html.duckduckgo.com/html/?q=FORTUNEMAKER+INVESTMENTS+CORPORATION+investigation
# Searching for: FORTUNEMAKER INVESTMENTS CORPORATION insolvency
# Error fetching results for query: FORTUNEMAKER+INVESTMENTS+CORPORATION+insolvency, Error: 403 Client Error: Forbidden for url: https://html.duckduckgo.com/html/?q=FORTUNEMAKER+INVESTMENTS+CORPORATION+insolvency
# Searching for: FORTUNEMAKER INVESTMENTS CORPORATION debt
# Error fetching results for query: FORTUNEMAKER+INVESTMENTS+CORPORATION+debt, Error: 403 Client Error: Forbidden for url: https://html.duckduckgo.com/html/?q=FORTUNEMAKER+INVESTMENTS+CORPORATION+debt
# Searching for: FORTUNEMAKER INVESTMENTS CORPORATION violation
# Error fetching results for query: FORTUNEMAKER+INVESTMENTS+CORPORATION+violation, Error: 403 Client Error: Forbidden for url: https://html.duckduckgo.com/html/?q=FORTUNEMAKER+INVESTMENTS+CORPORATION+violation
# Searching for: FORTUNEMAKER INVESTMENTS CORPORATION arrested
# Error fetching results for query: FORTUNEMAKER+INVESTMENTS+CORPORATION+arrested, Error: 403 Client Error: Forbidden for url: https://html.duckduckgo.com/html/?q=FORTUNEMAKER+INVESTMENTS+CORPORATION+arrested
# Searching for: FORTUNEMAKER INVESTMENTS CORPORATION sanctions
# Error fetching results for query: FORTUNEMAKER+INVESTMENTS+CORPORATION+sanctions, Error: 403 Client Error: Forbidden for url: https://html.duckduckgo.com/html/?q=FORTUNEMAKER+INVESTMENTS+CORPORATION+sanctions
# Searching for: FORTUNEMAKER INVESTMENTS CORPORATION litigation
# Error fetching results for query: FORTUNEMAKER+INVESTMENTS+CORPORATION+litigation, Error: 403 Client Error: Forbidden for url: https://html.duckduckgo.com/html/?q=FORTUNEMAKER+INVESTMENTS+CORPORATION+litigation
# Searching for: FORTUNEMAKER INVESTMENTS CORPORATION shell company
# Error fetching results for query: FORTUNEMAKER+INVESTMENTS+CORPORATION+shell+company, Error: 403 Client Error: Forbidden for url: https://html.duckduckgo.com/html/?q=FORTUNEMAKER+INVESTMENTS+CORPORATION+shell+company
# Searching for: FORTUNEMAKER INVESTMENTS CORPORATION blackmail
# Error fetching results for query: FORTUNEMAKER+INVESTMENTS+CORPORATION+blackmail, Error: 403 Client Error: Forbidden for url: https://html.duckduckgo.com/html/?q=FORTUNEMAKER+INVESTMENTS+CORPORATION+blackmail
# Searching for: 8808 HOLDING LIMITED court
# Error fetching results for query: 8808+HOLDING+LIMITED+court, Error: 403 Client Error: Forbidden for url: https://html.duckduckgo.com/html/?q=8808+HOLDING+LIMITED+court
# Searching for: 8808 HOLDING LIMITED criminal case
# Error fetching results for query: 8808+HOLDING+LIMITED+criminal+case, Error: 403 Client Error: Forbidden for url: https://html.duckduckgo.com/html/?q=8808+HOLDING+LIMITED+criminal+case
# Searching for: 8808 HOLDING LIMITED accusation
# Error fetching results for query: 8808+HOLDING+LIMITED+accusation, Error: 403 Client Error: Forbidden for url: https://html.duckduckgo.com/html/?q=8808+HOLDING+LIMITED+accusation
# Searching for: 8808 HOLDING LIMITED crime
# Error fetching results for query: 8808+HOLDING+LIMITED+crime, Error: 403 Client Error: Forbidden for url: https://html.duckduckgo.com/html/?q=8808+HOLDING+LIMITED+crime
# Searching for: 8808 HOLDING LIMITED corruption
# Error fetching results for query: 8808+HOLDING+LIMITED+corruption, Error: 403 Client Error: Forbidden for url: https://html.duckduckgo.com/html/?q=8808+HOLDING+LIMITED+corruption
# Searching for: 8808 HOLDING LIMITED penalty
# Error fetching results for query: 8808+HOLDING+LIMITED+penalty, Error: 403 Client Error: Forbidden for url: https://html.duckduckgo.com/html/?q=8808+HOLDING+LIMITED+penalty
# Searching for: 8808 HOLDING LIMITED investigation
# Error fetching results for query: 8808+HOLDING+LIMITED+investigation, Error: 403 Client Error: Forbidden for url: https://html.duckduckgo.com/html/?q=8808+HOLDING+LIMITED+investigation
# Searching for: 8808 HOLDING LIMITED insolvency
# Error fetching results for query: 8808+HOLDING+LIMITED+insolvency, Error: 403 Client Error: Forbidden for url: https://html.duckduckgo.com/html/?q=8808+HOLDING+LIMITED+insolvency
# Searching for: 8808 HOLDING LIMITED debt
# Error fetching results for query: 8808+HOLDING+LIMITED+debt, Error: 403 Client Error: Forbidden for url: https://html.duckduckgo.com/html/?q=8808+HOLDING+LIMITED+debt
# Searching for: 8808 HOLDING LIMITED violation
# Error fetching results for query: 8808+HOLDING+LIMITED+violation, Error: 403 Client Error: Forbidden for url: https://html.duckduckgo.com/html/?q=8808+HOLDING+LIMITED+violation
# Searching for: 8808 HOLDING LIMITED arrested
# Error fetching results for query: 8808+HOLDING+LIMITED+arrested, Error: 403 Client Error: Forbidden for url: https://html.duckduckgo.com/html/?q=8808+HOLDING+LIMITED+arrested
# Searching for: 8808 HOLDING LIMITED sanctions
# Error fetching results for query: 8808+HOLDING+LIMITED+sanctions, Error: 403 Client Error: Forbidden for url: https://html.duckduckgo.com/html/?q=8808+HOLDING+LIMITED+sanctions
# Searching for: 8808 HOLDING LIMITED litigation
# Error fetching results for query: 8808+HOLDING+LIMITED+litigation, Error: 403 Client Error: Forbidden for url: https://html.duckduckgo.com/html/?q=8808+HOLDING+LIMITED+litigation
# Searching for: 8808 HOLDING LIMITED shell company
# Error fetching results for query: 8808+HOLDING+LIMITED+shell+company, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=8808+HOLDING+LIMITED+shell+company (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f338cff9f90>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: 8808 HOLDING LIMITED blackmail
# Error fetching results for query: 8808+HOLDING+LIMITED+blackmail, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=8808+HOLDING+LIMITED+blackmail (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f3389d008e0>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: KENT DEVELOPMENT LIMITED court
# Error fetching results for query: KENT+DEVELOPMENT+LIMITED+court, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=KENT+DEVELOPMENT+LIMITED+court (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f3389d00940>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: KENT DEVELOPMENT LIMITED criminal case
# Error fetching results for query: KENT+DEVELOPMENT+LIMITED+criminal+case, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=KENT+DEVELOPMENT+LIMITED+criminal+case (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f3389d02ef0>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: KENT DEVELOPMENT LIMITED accusation
# Error fetching results for query: KENT+DEVELOPMENT+LIMITED+accusation, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=KENT+DEVELOPMENT+LIMITED+accusation (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f3389d028f0>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: KENT DEVELOPMENT LIMITED crime
# Error fetching results for query: KENT+DEVELOPMENT+LIMITED+crime, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=KENT+DEVELOPMENT+LIMITED+crime (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f338bd34eb0>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: KENT DEVELOPMENT LIMITED corruption
# Error fetching results for query: KENT+DEVELOPMENT+LIMITED+corruption, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=KENT+DEVELOPMENT+LIMITED+corruption (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f3389d032b0>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: KENT DEVELOPMENT LIMITED penalty
# Error fetching results for query: KENT+DEVELOPMENT+LIMITED+penalty, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=KENT+DEVELOPMENT+LIMITED+penalty (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f3389d00160>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: KENT DEVELOPMENT LIMITED investigation
# Error fetching results for query: KENT+DEVELOPMENT+LIMITED+investigation, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=KENT+DEVELOPMENT+LIMITED+investigation (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f3389d01f90>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: KENT DEVELOPMENT LIMITED insolvency
# Error fetching results for query: KENT+DEVELOPMENT+LIMITED+insolvency, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=KENT+DEVELOPMENT+LIMITED+insolvency (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f338dcbffd0>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: KENT DEVELOPMENT LIMITED debt
# Error fetching results for query: KENT+DEVELOPMENT+LIMITED+debt, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=KENT+DEVELOPMENT+LIMITED+debt (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f338cffa410>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: KENT DEVELOPMENT LIMITED violation
# Error fetching results for query: KENT+DEVELOPMENT+LIMITED+violation, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=KENT+DEVELOPMENT+LIMITED+violation (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f3389d03c40>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: KENT DEVELOPMENT LIMITED arrested
# Error fetching results for query: KENT+DEVELOPMENT+LIMITED+arrested, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=KENT+DEVELOPMENT+LIMITED+arrested (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f3389d02dd0>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: KENT DEVELOPMENT LIMITED sanctions
# Error fetching results for query: KENT+DEVELOPMENT+LIMITED+sanctions, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=KENT+DEVELOPMENT+LIMITED+sanctions (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f3389d03970>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: KENT DEVELOPMENT LIMITED litigation
# Error fetching results for query: KENT+DEVELOPMENT+LIMITED+litigation, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=KENT+DEVELOPMENT+LIMITED+litigation (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f3389d00190>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: KENT DEVELOPMENT LIMITED shell company
# Error fetching results for query: KENT+DEVELOPMENT+LIMITED+shell+company, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=KENT+DEVELOPMENT+LIMITED+shell+company (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f338bd34bb0>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: KENT DEVELOPMENT LIMITED blackmail
# Error fetching results for query: KENT+DEVELOPMENT+LIMITED+blackmail, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=KENT+DEVELOPMENT+LIMITED+blackmail (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f3389d00880>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: BONUS TRADE LIMITED court
# Error fetching results for query: BONUS+TRADE+LIMITED+court, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=BONUS+TRADE+LIMITED+court (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f3389d00940>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: BONUS TRADE LIMITED criminal case
# Error fetching results for query: BONUS+TRADE+LIMITED+criminal+case, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=BONUS+TRADE+LIMITED+criminal+case (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f3389d00640>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: BONUS TRADE LIMITED accusation
# Error fetching results for query: BONUS+TRADE+LIMITED+accusation, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=BONUS+TRADE+LIMITED+accusation (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f3389d00070>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: BONUS TRADE LIMITED crime
# Error fetching results for query: BONUS+TRADE+LIMITED+crime, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=BONUS+TRADE+LIMITED+crime (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f338cff9840>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: BONUS TRADE LIMITED corruption
# Error fetching results for query: BONUS+TRADE+LIMITED+corruption, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=BONUS+TRADE+LIMITED+corruption (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f3389d011e0>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: BONUS TRADE LIMITED penalty
# Error fetching results for query: BONUS+TRADE+LIMITED+penalty, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=BONUS+TRADE+LIMITED+penalty (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f3389d027d0>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: BONUS TRADE LIMITED investigation
# Error fetching results for query: BONUS+TRADE+LIMITED+investigation, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=BONUS+TRADE+LIMITED+investigation (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f3389d02a70>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: BONUS TRADE LIMITED insolvency
# Error fetching results for query: BONUS+TRADE+LIMITED+insolvency, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=BONUS+TRADE+LIMITED+insolvency (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f3389d02410>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: BONUS TRADE LIMITED debt
# Error fetching results for query: BONUS+TRADE+LIMITED+debt, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=BONUS+TRADE+LIMITED+debt (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f338bd35f90>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: BONUS TRADE LIMITED violation
# Error fetching results for query: BONUS+TRADE+LIMITED+violation, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=BONUS+TRADE+LIMITED+violation (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f3389d037f0>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: BONUS TRADE LIMITED arrested
# Error fetching results for query: BONUS+TRADE+LIMITED+arrested, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=BONUS+TRADE+LIMITED+arrested (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f3389d025c0>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: BONUS TRADE LIMITED sanctions
# Error fetching results for query: BONUS+TRADE+LIMITED+sanctions, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=BONUS+TRADE+LIMITED+sanctions (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f3389d012d0>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: BONUS TRADE LIMITED litigation
# Error fetching results for query: BONUS+TRADE+LIMITED+litigation, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=BONUS+TRADE+LIMITED+litigation (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f3389d02ad0>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: BONUS TRADE LIMITED shell company
# Error fetching results for query: BONUS+TRADE+LIMITED+shell+company, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=BONUS+TRADE+LIMITED+shell+company (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f338cffa410>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: BONUS TRADE LIMITED blackmail
# Error fetching results for query: BONUS+TRADE+LIMITED+blackmail, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=BONUS+TRADE+LIMITED+blackmail (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f3389d00e50>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: AMARANDAN LTD. court
# Error fetching results for query: AMARANDAN+LTD.+court, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=AMARANDAN+LTD.+court (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f3389d00160>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: AMARANDAN LTD. criminal case
# Error fetching results for query: AMARANDAN+LTD.+criminal+case, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=AMARANDAN+LTD.+criminal+case (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f3389d03280>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: AMARANDAN LTD. accusation
# Error fetching results for query: AMARANDAN+LTD.+accusation, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=AMARANDAN+LTD.+accusation (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f338998bd30>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: AMARANDAN LTD. crime
# Error fetching results for query: AMARANDAN+LTD.+crime, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=AMARANDAN+LTD.+crime (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f338cffab30>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: AMARANDAN LTD. corruption
# Error fetching results for query: AMARANDAN+LTD.+corruption, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=AMARANDAN+LTD.+corruption (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f3389d01030>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: AMARANDAN LTD. penalty
# Error fetching results for query: AMARANDAN+LTD.+penalty, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=AMARANDAN+LTD.+penalty (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f3389d03040>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: AMARANDAN LTD. investigation
# Error fetching results for query: AMARANDAN+LTD.+investigation, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=AMARANDAN+LTD.+investigation (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f3389d02a40>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: AMARANDAN LTD. insolvency
# Error fetching results for query: AMARANDAN+LTD.+insolvency, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=AMARANDAN+LTD.+insolvency (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f3389d00640>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: AMARANDAN LTD. debt
# Error fetching results for query: AMARANDAN+LTD.+debt, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=AMARANDAN+LTD.+debt (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f338bd342e0>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: AMARANDAN LTD. violation
# Error fetching results for query: AMARANDAN+LTD.+violation, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=AMARANDAN+LTD.+violation (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f3389d02b90>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: AMARANDAN LTD. arrested
# Error fetching results for query: AMARANDAN+LTD.+arrested, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=AMARANDAN+LTD.+arrested (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f3389d02bc0>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: AMARANDAN LTD. sanctions
# Error fetching results for query: AMARANDAN+LTD.+sanctions, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=AMARANDAN+LTD.+sanctions (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f3389d02890>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: AMARANDAN LTD. litigation
# Error fetching results for query: AMARANDAN+LTD.+litigation, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=AMARANDAN+LTD.+litigation (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f3389d00b20>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: AMARANDAN LTD. shell company
# Error fetching results for query: AMARANDAN+LTD.+shell+company, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=AMARANDAN+LTD.+shell+company (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f3389d02bc0>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: AMARANDAN LTD. blackmail
# Error fetching results for query: AMARANDAN+LTD.+blackmail, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=AMARANDAN+LTD.+blackmail (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f3389d038e0>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: NEW IDEA LIMITED court
# Error fetching results for query: NEW+IDEA+LIMITED+court, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=NEW+IDEA+LIMITED+court (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f338bd35660>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: NEW IDEA LIMITED criminal case
# Error fetching results for query: NEW+IDEA+LIMITED+criminal+case, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=NEW+IDEA+LIMITED+criminal+case (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f338cffb880>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: NEW IDEA LIMITED accusation
# Error fetching results for query: NEW+IDEA+LIMITED+accusation, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=NEW+IDEA+LIMITED+accusation (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f338998ba00>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: NEW IDEA LIMITED crime
# Error fetching results for query: NEW+IDEA+LIMITED+crime, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=NEW+IDEA+LIMITED+crime (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f338bd34a30>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: NEW IDEA LIMITED corruption
# Error fetching results for query: NEW+IDEA+LIMITED+corruption, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=NEW+IDEA+LIMITED+corruption (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f3389d00310>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: NEW IDEA LIMITED penalty
# Error fetching results for query: NEW+IDEA+LIMITED+penalty, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=NEW+IDEA+LIMITED+penalty (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f3389d00220>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: NEW IDEA LIMITED investigation
# Error fetching results for query: NEW+IDEA+LIMITED+investigation, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=NEW+IDEA+LIMITED+investigation (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f3389d03610>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: NEW IDEA LIMITED insolvency
# Error fetching results for query: NEW+IDEA+LIMITED+insolvency, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=NEW+IDEA+LIMITED+insolvency (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f3389d00e20>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: NEW IDEA LIMITED debt
# Error fetching results for query: NEW+IDEA+LIMITED+debt, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=NEW+IDEA+LIMITED+debt (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f338cff8be0>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: NEW IDEA LIMITED violation
# Error fetching results for query: NEW+IDEA+LIMITED+violation, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=NEW+IDEA+LIMITED+violation (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f3389d01360>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: NEW IDEA LIMITED arrested
# Error fetching results for query: NEW+IDEA+LIMITED+arrested, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=NEW+IDEA+LIMITED+arrested (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f3389d02bf0>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: NEW IDEA LIMITED sanctions
# Error fetching results for query: NEW+IDEA+LIMITED+sanctions, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=NEW+IDEA+LIMITED+sanctions (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f3389989000>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: NEW IDEA LIMITED litigation
# Error fetching results for query: NEW+IDEA+LIMITED+litigation, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=NEW+IDEA+LIMITED+litigation (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f33899887c0>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: NEW IDEA LIMITED shell company
# Error fetching results for query: NEW+IDEA+LIMITED+shell+company, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=NEW+IDEA+LIMITED+shell+company (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f338bd35fc0>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))
# Searching for: NEW IDEA LIMITED blackmail
# Error fetching results for query: NEW+IDEA+LIMITED+blackmail, Error: HTTPSConnectionPool(host='html.duckduckgo.com', port=443): Max retries exceeded with url: /html/?q=NEW+IDEA+LIMITED+blackmail (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7f3389d01ed0>, 'Connection to html.duckduckgo.com timed out. (connect timeout=10)'))

# %%
import os
import json
import requests
from bs4 import BeautifulSoup
import time
import pandas as pd
import csv
from urllib.parse import quote

# Load the CSV file
file_path = 'nodes-entities.csv'
df = pd.read_csv(file_path, usecols=['name'])
companies = df['name'].dropna().unique()[:10]  # Limit to first 10 companies

# Keywords to search for
keywords = [
    "court", "criminal case", "accusation", "crime", "corruption", "penalty",
    "investigation", "insolvency", "debt", "violation", "arrested", "sanctions",
    "litigation", "shell company", "blackmail"
]

# Output file to save results
output_file = "company_search_results.csv"

# Headers to mimic a browser visit
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36"
}

def search_company_with_keywords(company, keywords):
    # Use quotes around company name to improve accuracy and handle special characters
    query = f'"{company}" ' + ' OR '.join([f'"{kw}"' for kw in keywords])
    url = f"https://www.google.com/search?q={quote(query)}"
    response = requests.get(url, headers=headers)
    if response.status_code != 200:
        print(f"Failed to fetch results for {company}: {response.status_code}")
        return []

    soup = BeautifulSoup(response.text, "html.parser")
    search_results = []

    for g in soup.find_all('div', class_='tF2Cxc'):
        title = g.find('h3').text if g.find('h3') else ""
        link = g.find('a')['href'] if g.find('a') else ""
        snippet = g.find('span', class_='aCOpRe').text if g.find('span', class_='aCOpRe') else ""

        if title and link:
            matching_keywords = ', '.join([kw for kw in keywords if kw.lower() in title.lower() or kw.lower() in snippet.lower()])
            search_results.append({
                "company": company,
                "matching_keywords": matching_keywords if matching_keywords else "None",
                "link": link
            })

    return search_results

def main():
    all_results = []

    for company in companies:
        print(f"Searching for: {company}")
        search_results = search_company_with_keywords(company, keywords)
        all_results.extend(search_results)
        time.sleep(2)  # Sleep to avoid being blocked by Google

    # Save results to a CSV file
    with open(output_file, "w", newline="", encoding="utf-8") as csvfile:
        fieldnames = ["company", "matching_keywords", "link"]
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

        writer.writeheader()
        for result in all_results:
            writer.writerow(result)

    print(f"Results saved to {output_file}")

if __name__ == "__main__":
    main()
# Out:
# Searching for: TIANSHENG INDUSTRY AND TRADING CO., LTD.
# Searching for: NINGBO SUNRISE ENTERPRISES UNITED CO., LTD.
# Searching for: HOTFOCUS CO., LTD.
# Searching for: SKY-BLUE GIFTS & TOYS CO., LTD.
# Searching for: FORTUNEMAKER INVESTMENTS CORPORATION
# Searching for: 8808 HOLDING LIMITED
# Searching for: KENT DEVELOPMENT LIMITED
# Searching for: BONUS TRADE LIMITED
# Searching for: AMARANDAN LTD.
# Searching for: NEW IDEA LIMITED
# Results saved to company_search_results.csv

# %%
import os
import json
import csv
import requests
from bs4 import BeautifulSoup
import time
from urllib.parse import quote

# Load the CSV file
file_path = 'nodes-entities.csv'
df = pd.read_csv(file_path, usecols=['name'])
companies = df['name'].dropna().unique()[:10]  # Limit to first 10 companies

# Keywords to search for
keywords = [
    "court", "criminal case", "accusation", "crime", "corruption", "penalty",
    "investigation", "insolvency", "debt", "violation", "arrested", "sanctions",
    "litigation", "shell company", "blackmail"
]

# Output file to save results
output_file = "company_search_results.csv"

# Headers to mimic a browser visit
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36"
}

def search_company_with_keywords(company, keywords):
    # Use quotes around company name to improve accuracy and handle special characters
    query = f'"{company}" ' + ' OR '.join([f'"{kw}"' for kw in keywords])
    url = f"https://www.google.com/search?q={quote(query)}"
    response = requests.get(url, headers=headers)
    if response.status_code != 200:
        print(f"Failed to fetch results for {company}: {response.status_code}")
        return []

    soup = BeautifulSoup(response.text, "html.parser")
    search_results = []

    for g in soup.find_all('div', class_='tF2Cxc'):
        title = g.find('h3').text if g.find('h3') else ""
        link = g.find('a')['href'] if g.find('a') else ""
        snippet = g.find('span', class_='aCOpRe').text if g.find('span', class_='aCOpRe') else ""

        if title and link:
            matching_keywords = ', '.join([kw for kw in keywords if kw.lower() in title.lower() or kw.lower() in snippet.lower()])
            search_results.append({
                "company": company,
                "matching_keywords": matching_keywords if matching_keywords else "None",
                "link": link
            })

    # Remove duplicate links
    unique_results = {result['link']: result for result in search_results}.values()
    return list(unique_results)

def main():
    all_results = []

    for company in companies:
        print(f"Searching for: {company}")
        search_results = search_company_with_keywords(company, keywords)
        all_results.extend(search_results)
        time.sleep(2)  # Sleep to avoid being blocked by Google

    # Save results to a CSV file
    with open(output_file, "w", newline="", encoding="utf-8") as csvfile:
        fieldnames = ["company", "matching_keywords", "link"]
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

        writer.writeheader()
        for result in all_results:
            writer.writerow(result)

    print(f"Results saved to {output_file}")

if __name__ == "__main__":
    main()
# Out:
# Searching for: TIANSHENG INDUSTRY AND TRADING CO., LTD.
# Searching for: NINGBO SUNRISE ENTERPRISES UNITED CO., LTD.
# Searching for: HOTFOCUS CO., LTD.
# Searching for: SKY-BLUE GIFTS & TOYS CO., LTD.
# Searching for: FORTUNEMAKER INVESTMENTS CORPORATION
# Searching for: 8808 HOLDING LIMITED
# Searching for: KENT DEVELOPMENT LIMITED
# Searching for: BONUS TRADE LIMITED
# Searching for: AMARANDAN LTD.
# Searching for: NEW IDEA LIMITED
# Results saved to company_search_results.csv
